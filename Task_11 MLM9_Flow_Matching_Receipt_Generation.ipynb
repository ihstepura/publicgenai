# %% [markdown]
# <a href="https://colab.research.google.com/github/ihstepura/publicgenai/blob/main/Task_11%20MLM9_Flow_Matching_Receipt_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Flow Matching for Receipt Generation
#
# This notebook demonstrates how to train a Flow Matching model to generate synthetic receipt images. We'll cover the entire process from data preparation to model training and image generation. The goal is to create a generative model that can produce realistic-looking receipts based on a small dataset of real receipts.

# %% [markdown]
# ## Setup and Hyperparameters
#
# This section imports necessary libraries and defines global hyperparameters (`HPARAMS`) that configure our model and training process. Understanding these parameters is crucial for customizing the model's behavior and performance.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision.utils import make_grid
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import random
import os
from PIL import Image, ImageDraw

# Check for GPU availability and set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define Hyperparameters
HPARAMS = {
    "img_size": 256,         # Size of the generated images (e.g., 256x256 pixels)
    "inference_steps": 100,  # Number of steps for the ODE solver during sampling (higher = better quality, slower)
    "batch_size": 32,        # Number of images processed per training step
    "lr": 1e-4,              # Learning rate for the Adam optimizer
    "epochs": 50,            # Number of full passes through the training dataset
    "channels": 1,           # Number of image channels (1 for grayscale, 3 for RGB)
    "num_classes": 1         # Number of distinct classes the model should generate (here, only 'receipts')
}
print("Hyperparameters:", HPARAMS)
# Out:
# Using device: cuda
# Hyperparameters: {'img_size': 256, 'inference_steps': 100, 'batch_size': 32, 'lr': 0.0001, 'epochs': 50, 'channels': 1, 'num_classes': 1}

# %% [markdown]
# ## Data Extraction
#
# Before we can train our model, we need to extract the receipt images from the provided ZIP file. This step uses a shell command to decompress the archive into a designated directory.

# %%
# !unzip /content/floorplans_v2-20251223T170650Z-3-001.zip
print("Zip file extracted to 'receipt_images' directory.")
# Out:
# Archive:  /content/floorplans_v2-20251223T170650Z-3-001.zip
#   inflating: floorplans_v2/floorplan_00992.jpg
#   inflating: floorplans_v2/floorplan_00968.jpg
#   inflating: floorplans_v2/floorplan_00980.jpg
#   inflating: floorplans_v2/floorplan_00986.jpg
#   inflating: floorplans_v2/floorplan_00984.jpg
#   inflating: floorplans_v2/floorplan_00994.jpg
#   inflating: floorplans_v2/floorplan_00998.jpg
#   inflating: floorplans_v2/floorplan_00973.jpg
#   inflating: floorplans_v2/floorplan_00981.jpg
#   inflating: floorplans_v2/floorplan_00991.jpg
#   inflating: floorplans_v2/floorplan_00983.jpg
#   inflating: floorplans_v2/floorplan_00990.jpg
#   inflating: floorplans_v2/floorplan_00979.jpg
#   inflating: floorplans_v2/floorplan_00982.jpg
#   inflating: floorplans_v2/floorplan_00974.jpg
#   inflating: floorplans_v2/floorplan_00977.jpg
#   inflating: floorplans_v2/floorplan_00975.jpg
#   inflating: floorplans_v2/floorplan_00987.jpg
#   inflating: floorplans_v2/floorplan_00996.jpg
#   inflating: floorplans_v2/floorplan_00970.jpg
#   inflating: floorplans_v2/floorplan_00989.jpg
#   inflating: floorplans_v2/floorplan_00971.jpg
#   inflating: floorplans_v2/floorplan_00985.jpg
#   inflating: floorplans_v2/floorplan_00978.jpg
#   inflating: floorplans_v2/floorplan_00997.jpg
#   inflating: floorplans_v2/floorplan_00972.jpg
#   inflating: floorplans_v2/floorplan_00993.jpg
#   inflating: floorplans_v2/floorplan_00988.jpg
#   inflating: floorplans_v2/floorplan_00999.jpg
#   inflating: floorplans_v2/floorplan_00995.jpg
#   inflating: floorplans_v2/floorplan_00976.jpg
#   inflating: floorplans_v2/floorplan_00967.jpg
#   inflating: floorplans_v2/floorplan_00963.jpg
#   inflating: floorplans_v2/floorplan_00962.jpg
#   inflating: floorplans_v2/floorplan_00961.jpg
#   inflating: floorplans_v2/floorplan_00966.jpg
#   inflating: floorplans_v2/floorplan_00960.jpg
#   inflating: floorplans_v2/floorplan_00956.jpg
#   inflating: floorplans_v2/floorplan_00958.jpg
#   inflating: floorplans_v2/floorplan_00955.jpg
#   inflating: floorplans_v2/floorplan_00969.jpg
#   inflating: floorplans_v2/floorplan_00959.jpg
#   inflating: floorplans_v2/floorplan_00948.jpg
#   inflating: floorplans_v2/floorplan_00951.jpg
#   inflating: floorplans_v2/floorplan_00964.jpg
#   inflating: floorplans_v2/floorplan_00957.jpg
#   inflating: floorplans_v2/floorplan_00952.jpg
#   inflating: floorplans_v2/floorplan_00954.jpg
#   inflating: floorplans_v2/floorplan_00953.jpg
#   inflating: floorplans_v2/floorplan_00950.jpg
#   inflating: floorplans_v2/floorplan_00965.jpg
#   inflating: floorplans_v2/floorplan_00937.jpg
#   inflating: floorplans_v2/floorplan_00940.jpg
#   inflating: floorplans_v2/floorplan_00938.jpg
#   inflating: floorplans_v2/floorplan_00941.jpg
#   inflating: floorplans_v2/floorplan_00946.jpg
#   inflating: floorplans_v2/floorplan_00939.jpg
#   inflating: floorplans_v2/floorplan_00945.jpg
#   inflating: floorplans_v2/floorplan_00947.jpg
#   inflating: floorplans_v2/floorplan_00935.jpg
#   inflating: floorplans_v2/floorplan_00936.jpg
#   inflating: floorplans_v2/floorplan_00934.jpg
#   inflating: floorplans_v2/floorplan_00949.jpg
#   inflating: floorplans_v2/floorplan_00933.jpg
#   inflating: floorplans_v2/floorplan_00929.jpg
#   inflating: floorplans_v2/floorplan_00943.jpg
#   inflating: floorplans_v2/floorplan_00944.jpg
#   inflating: floorplans_v2/floorplan_00931.jpg
#   inflating: floorplans_v2/floorplan_00930.jpg
#   inflating: floorplans_v2/floorplan_00925.jpg
#   inflating: floorplans_v2/floorplan_00928.jpg
#   inflating: floorplans_v2/floorplan_00942.jpg
#   inflating: floorplans_v2/floorplan_00932.jpg
#   inflating: floorplans_v2/floorplan_00926.jpg
#   inflating: floorplans_v2/floorplan_00919.jpg
#   inflating: floorplans_v2/floorplan_00922.jpg
#   inflating: floorplans_v2/floorplan_00924.jpg
#   inflating: floorplans_v2/floorplan_00927.jpg
#   inflating: floorplans_v2/floorplan_00920.jpg
#   inflating: floorplans_v2/floorplan_00923.jpg
#   inflating: floorplans_v2/floorplan_00921.jpg
#   inflating: floorplans_v2/floorplan_00918.jpg
#   inflating: floorplans_v2/floorplan_00917.jpg
#   inflating: floorplans_v2/floorplan_00911.jpg
#   inflating: floorplans_v2/floorplan_00915.jpg
#   inflating: floorplans_v2/floorplan_00916.jpg
#   inflating: floorplans_v2/floorplan_00909.jpg
#   inflating: floorplans_v2/floorplan_00910.jpg
#   inflating: floorplans_v2/floorplan_00913.jpg
#   inflating: floorplans_v2/floorplan_00912.jpg
#   inflating: floorplans_v2/floorplan_00914.jpg
#   inflating: floorplans_v2/floorplan_00902.jpg
#   inflating: floorplans_v2/floorplan_00907.jpg
#   inflating: floorplans_v2/floorplan_00908.jpg
#   inflating: floorplans_v2/floorplan_00899.jpg
#   inflating: floorplans_v2/floorplan_00905.jpg
#   inflating: floorplans_v2/floorplan_00896.jpg
#   inflating: floorplans_v2/floorplan_00901.jpg
#   inflating: floorplans_v2/floorplan_00904.jpg
#   inflating: floorplans_v2/floorplan_00897.jpg
#   inflating: floorplans_v2/floorplan_00895.jpg
#   inflating: floorplans_v2/floorplan_00903.jpg
#   inflating: floorplans_v2/floorplan_00898.jpg
#   inflating: floorplans_v2/floorplan_00906.jpg
#   inflating: floorplans_v2/floorplan_00900.jpg
#   inflating: floorplans_v2/floorplan_00891.jpg
#   inflating: floorplans_v2/floorplan_00892.jpg
#   inflating: floorplans_v2/floorplan_00893.jpg
#   inflating: floorplans_v2/floorplan_00889.jpg
#   inflating: floorplans_v2/floorplan_00890.jpg
#   inflating: floorplans_v2/floorplan_00884.jpg
#   inflating: floorplans_v2/floorplan_00888.jpg
#   inflating: floorplans_v2/floorplan_00894.jpg
#   inflating: floorplans_v2/floorplan_00887.jpg
#   inflating: floorplans_v2/floorplan_00885.jpg
#   inflating: floorplans_v2/floorplan_00880.jpg
#   inflating: floorplans_v2/floorplan_00883.jpg
#   inflating: floorplans_v2/floorplan_00878.jpg
#   inflating: floorplans_v2/floorplan_00876.jpg
#   inflating: floorplans_v2/floorplan_00886.jpg
#   inflating: floorplans_v2/floorplan_00881.jpg
#   inflating: floorplans_v2/floorplan_00877.jpg
#   inflating: floorplans_v2/floorplan_00874.jpg
#   inflating: floorplans_v2/floorplan_00875.jpg
#   inflating: floorplans_v2/floorplan_00882.jpg
#   inflating: floorplans_v2/floorplan_00872.jpg
#   inflating: floorplans_v2/floorplan_00879.jpg
#   inflating: floorplans_v2/floorplan_00871.jpg
#   inflating: floorplans_v2/floorplan_00864.jpg
#   inflating: floorplans_v2/floorplan_00869.jpg
#   inflating: floorplans_v2/floorplan_00870.jpg
#   inflating: floorplans_v2/floorplan_00867.jpg
#   inflating: floorplans_v2/floorplan_00865.jpg
#   inflating: floorplans_v2/floorplan_00866.jpg
#   inflating: floorplans_v2/floorplan_00863.jpg
#   inflating: floorplans_v2/floorplan_00861.jpg
#   inflating: floorplans_v2/floorplan_00860.jpg
#   inflating: floorplans_v2/floorplan_00868.jpg
#   inflating: floorplans_v2/floorplan_00856.jpg
#   inflating: floorplans_v2/floorplan_00855.jpg
#   inflating: floorplans_v2/floorplan_00849.jpg
#   inflating: floorplans_v2/floorplan_00859.jpg
#   inflating: floorplans_v2/floorplan_00858.jpg
#   inflating: floorplans_v2/floorplan_00854.jpg
#   inflating: floorplans_v2/floorplan_00848.jpg
#   inflating: floorplans_v2/floorplan_00851.jpg
#   inflating: floorplans_v2/floorplan_00857.jpg
#   inflating: floorplans_v2/floorplan_00852.jpg
#   inflating: floorplans_v2/floorplan_00873.jpg
#   inflating: floorplans_v2/floorplan_00847.jpg
#   inflating: floorplans_v2/floorplan_00839.jpg
#   inflating: floorplans_v2/floorplan_00842.jpg
#   inflating: floorplans_v2/floorplan_00862.jpg
#   inflating: floorplans_v2/floorplan_00845.jpg
#   inflating: floorplans_v2/floorplan_00846.jpg
#   inflating: floorplans_v2/floorplan_00853.jpg
#   inflating: floorplans_v2/floorplan_00841.jpg
#   inflating: floorplans_v2/floorplan_00836.jpg
#   inflating: floorplans_v2/floorplan_00838.jpg
#   inflating: floorplans_v2/floorplan_00834.jpg
#   inflating: floorplans_v2/floorplan_00833.jpg
#   inflating: floorplans_v2/floorplan_00840.jpg
#   inflating: floorplans_v2/floorplan_00831.jpg
#   inflating: floorplans_v2/floorplan_00844.jpg
#   inflating: floorplans_v2/floorplan_00835.jpg
#   inflating: floorplans_v2/floorplan_00837.jpg
#   inflating: floorplans_v2/floorplan_00843.jpg
#   inflating: floorplans_v2/floorplan_00830.jpg
#   inflating: floorplans_v2/floorplan_00832.jpg
#   inflating: floorplans_v2/floorplan_00850.jpg
#   inflating: floorplans_v2/floorplan_00826.jpg
#   inflating: floorplans_v2/floorplan_00828.jpg
#   inflating: floorplans_v2/floorplan_00825.jpg
#   inflating: floorplans_v2/floorplan_00829.jpg
#   inflating: floorplans_v2/floorplan_00827.jpg
#   inflating: floorplans_v2/floorplan_00822.jpg
#   inflating: floorplans_v2/floorplan_00823.jpg
#   inflating: floorplans_v2/floorplan_00817.jpg
#   inflating: floorplans_v2/floorplan_00821.jpg
#   inflating: floorplans_v2/floorplan_00816.jpg
#   inflating: floorplans_v2/floorplan_00818.jpg
#   inflating: floorplans_v2/floorplan_00824.jpg
#   inflating: floorplans_v2/floorplan_00820.jpg
#   inflating: floorplans_v2/floorplan_00819.jpg
#   inflating: floorplans_v2/floorplan_00813.jpg
#   inflating: floorplans_v2/floorplan_00815.jpg
#   inflating: floorplans_v2/floorplan_00812.jpg
#   inflating: floorplans_v2/floorplan_00811.jpg
#   inflating: floorplans_v2/floorplan_00810.jpg
#   inflating: floorplans_v2/floorplan_00806.jpg
#   inflating: floorplans_v2/floorplan_00807.jpg
#   inflating: floorplans_v2/floorplan_00808.jpg
#   inflating: floorplans_v2/floorplan_00814.jpg
#   inflating: floorplans_v2/floorplan_00802.jpg
#   inflating: floorplans_v2/floorplan_00803.jpg
#   inflating: floorplans_v2/floorplan_00804.jpg
#   inflating: floorplans_v2/floorplan_00801.jpg
#   inflating: floorplans_v2/floorplan_00805.jpg
#   inflating: floorplans_v2/floorplan_00809.jpg
#   inflating: floorplans_v2/floorplan_00800.jpg
#   inflating: floorplans_v2/floorplan_00796.jpg
#   inflating: floorplans_v2/floorplan_00795.jpg
#   inflating: floorplans_v2/floorplan_00798.jpg
#   inflating: floorplans_v2/floorplan_00792.jpg
#   inflating: floorplans_v2/floorplan_00793.jpg
#   inflating: floorplans_v2/floorplan_00787.jpg
#   inflating: floorplans_v2/floorplan_00790.jpg
#   inflating: floorplans_v2/floorplan_00797.jpg
#   inflating: floorplans_v2/floorplan_00794.jpg
#   inflating: floorplans_v2/floorplan_00785.jpg
#   inflating: floorplans_v2/floorplan_00782.jpg
#   inflating: floorplans_v2/floorplan_00788.jpg
#   inflating: floorplans_v2/floorplan_00786.jpg
#   inflating: floorplans_v2/floorplan_00783.jpg
#   inflating: floorplans_v2/floorplan_00789.jpg
#   inflating: floorplans_v2/floorplan_00799.jpg
#   inflating: floorplans_v2/floorplan_00781.jpg
#   inflating: floorplans_v2/floorplan_00778.jpg
#   inflating: floorplans_v2/floorplan_00774.jpg
#   inflating: floorplans_v2/floorplan_00777.jpg
#   inflating: floorplans_v2/floorplan_00773.jpg
#   inflating: floorplans_v2/floorplan_00771.jpg
#   inflating: floorplans_v2/floorplan_00780.jpg
#   inflating: floorplans_v2/floorplan_00784.jpg
#   inflating: floorplans_v2/floorplan_00772.jpg
#   inflating: floorplans_v2/floorplan_00764.jpg
#   inflating: floorplans_v2/floorplan_00767.jpg
#   inflating: floorplans_v2/floorplan_00765.jpg
#   inflating: floorplans_v2/floorplan_00791.jpg
#   inflating: floorplans_v2/floorplan_00776.jpg
#   inflating: floorplans_v2/floorplan_00766.jpg
#   inflating: floorplans_v2/floorplan_00768.jpg
#   inflating: floorplans_v2/floorplan_00761.jpg
#   inflating: floorplans_v2/floorplan_00770.jpg
#   inflating: floorplans_v2/floorplan_00769.jpg
#   inflating: floorplans_v2/floorplan_00762.jpg
#   inflating: floorplans_v2/floorplan_00756.jpg
#   inflating: floorplans_v2/floorplan_00758.jpg
#   inflating: floorplans_v2/floorplan_00755.jpg
#   inflating: floorplans_v2/floorplan_00779.jpg
#   inflating: floorplans_v2/floorplan_00757.jpg
#   inflating: floorplans_v2/floorplan_00753.jpg
#   inflating: floorplans_v2/floorplan_00759.jpg
#   inflating: floorplans_v2/floorplan_00751.jpg
#   inflating: floorplans_v2/floorplan_00760.jpg
#   inflating: floorplans_v2/floorplan_00775.jpg
#   inflating: floorplans_v2/floorplan_00750.jpg
#   inflating: floorplans_v2/floorplan_00752.jpg
#   inflating: floorplans_v2/floorplan_00754.jpg
#   inflating: floorplans_v2/floorplan_00749.jpg
#   inflating: floorplans_v2/floorplan_00747.jpg
#   inflating: floorplans_v2/floorplan_00763.jpg
#   inflating: floorplans_v2/floorplan_00742.jpg
#   inflating: floorplans_v2/floorplan_00744.jpg
#   inflating: floorplans_v2/floorplan_00746.jpg
#   inflating: floorplans_v2/floorplan_00740.jpg
#   inflating: floorplans_v2/floorplan_00745.jpg
#   inflating: floorplans_v2/floorplan_00736.jpg
#   inflating: floorplans_v2/floorplan_00743.jpg
#   inflating: floorplans_v2/floorplan_00741.jpg
#   inflating: floorplans_v2/floorplan_00734.jpg
#   inflating: floorplans_v2/floorplan_00748.jpg
#   inflating: floorplans_v2/floorplan_00733.jpg
#   inflating: floorplans_v2/floorplan_00738.jpg
#   inflating: floorplans_v2/floorplan_00735.jpg
#   inflating: floorplans_v2/floorplan_00732.jpg
#   inflating: floorplans_v2/floorplan_00739.jpg
#   inflating: floorplans_v2/floorplan_00731.jpg
#   inflating: floorplans_v2/floorplan_00726.jpg
#   inflating: floorplans_v2/floorplan_00729.jpg
#   inflating: floorplans_v2/floorplan_00730.jpg
#   inflating: floorplans_v2/floorplan_00725.jpg
#   inflating: floorplans_v2/floorplan_00723.jpg
#   inflating: floorplans_v2/floorplan_00724.jpg
#   inflating: floorplans_v2/floorplan_00737.jpg
#   inflating: floorplans_v2/floorplan_00728.jpg
#   inflating: floorplans_v2/floorplan_00721.jpg
#   inflating: floorplans_v2/floorplan_00722.jpg
#   inflating: floorplans_v2/floorplan_00727.jpg
#   inflating: floorplans_v2/floorplan_00717.jpg
#   inflating: floorplans_v2/floorplan_00711.jpg
#   inflating: floorplans_v2/floorplan_00718.jpg
#   inflating: floorplans_v2/floorplan_00715.jpg
#   inflating: floorplans_v2/floorplan_00719.jpg
#   inflating: floorplans_v2/floorplan_00714.jpg
#   inflating: floorplans_v2/floorplan_00712.jpg
#   inflating: floorplans_v2/floorplan_00713.jpg
#   inflating: floorplans_v2/floorplan_00710.jpg
#   inflating: floorplans_v2/floorplan_00709.jpg
#   inflating: floorplans_v2/floorplan_00708.jpg
#   inflating: floorplans_v2/floorplan_00716.jpg
#   inflating: floorplans_v2/floorplan_00702.jpg
#   inflating: floorplans_v2/floorplan_00706.jpg
#   inflating: floorplans_v2/floorplan_00704.jpg
#   inflating: floorplans_v2/floorplan_00705.jpg
#   inflating: floorplans_v2/floorplan_00700.jpg
#   inflating: floorplans_v2/floorplan_00703.jpg
#   inflating: floorplans_v2/floorplan_00720.jpg
#   inflating: floorplans_v2/floorplan_00701.jpg
#   inflating: floorplans_v2/floorplan_00707.jpg
#   inflating: floorplans_v2/floorplan_00698.jpg
#   inflating: floorplans_v2/floorplan_00693.jpg
#   inflating: floorplans_v2/floorplan_00694.jpg
#   inflating: floorplans_v2/floorplan_00695.jpg
#   inflating: floorplans_v2/floorplan_00697.jpg
#   inflating: floorplans_v2/floorplan_00690.jpg
#   inflating: floorplans_v2/floorplan_00691.jpg
#   inflating: floorplans_v2/floorplan_00696.jpg
#   inflating: floorplans_v2/floorplan_00689.jpg
#   inflating: floorplans_v2/floorplan_00692.jpg
#   inflating: floorplans_v2/floorplan_00688.jpg
#   inflating: floorplans_v2/floorplan_00687.jpg
#   inflating: floorplans_v2/floorplan_00686.jpg
#   inflating: floorplans_v2/floorplan_00685.jpg
#   inflating: floorplans_v2/floorplan_00682.jpg
#   inflating: floorplans_v2/floorplan_00681.jpg
#   inflating: floorplans_v2/floorplan_00683.jpg
#   inflating: floorplans_v2/floorplan_00679.jpg
#   inflating: floorplans_v2/floorplan_00684.jpg
#   inflating: floorplans_v2/floorplan_00699.jpg
#   inflating: floorplans_v2/floorplan_00674.jpg
#   inflating: floorplans_v2/floorplan_00678.jpg
#   inflating: floorplans_v2/floorplan_00680.jpg
#   inflating: floorplans_v2/floorplan_00675.jpg
#   inflating: floorplans_v2/floorplan_00676.jpg
#   inflating: floorplans_v2/floorplan_00673.jpg
#   inflating: floorplans_v2/floorplan_00668.jpg
#   inflating: floorplans_v2/floorplan_00677.jpg
#   inflating: floorplans_v2/floorplan_00671.jpg
#   inflating: floorplans_v2/floorplan_00667.jpg
#   inflating: floorplans_v2/floorplan_00672.jpg
#   inflating: floorplans_v2/floorplan_00666.jpg
#   inflating: floorplans_v2/floorplan_00669.jpg
#   inflating: floorplans_v2/floorplan_00670.jpg
#   inflating: floorplans_v2/floorplan_00662.jpg
#   inflating: floorplans_v2/floorplan_00663.jpg
#   inflating: floorplans_v2/floorplan_00665.jpg
#   inflating: floorplans_v2/floorplan_00664.jpg
#   inflating: floorplans_v2/floorplan_00661.jpg
#   inflating: floorplans_v2/floorplan_00660.jpg
#   inflating: floorplans_v2/floorplan_00658.jpg
#   inflating: floorplans_v2/floorplan_00659.jpg
#   inflating: floorplans_v2/floorplan_00652.jpg
#   inflating: floorplans_v2/floorplan_00655.jpg
#   inflating: floorplans_v2/floorplan_00651.jpg
#   inflating: floorplans_v2/floorplan_00657.jpg
#   inflating: floorplans_v2/floorplan_00656.jpg
#   inflating: floorplans_v2/floorplan_00647.jpg
#   inflating: floorplans_v2/floorplan_00650.jpg
#   inflating: floorplans_v2/floorplan_00648.jpg
#   inflating: floorplans_v2/floorplan_00645.jpg
#   inflating: floorplans_v2/floorplan_00646.jpg
#   inflating: floorplans_v2/floorplan_00649.jpg
#   inflating: floorplans_v2/floorplan_00639.jpg
#   inflating: floorplans_v2/floorplan_00643.jpg
#   inflating: floorplans_v2/floorplan_00641.jpg
#   inflating: floorplans_v2/floorplan_00636.jpg
#   inflating: floorplans_v2/floorplan_00640.jpg
#   inflating: floorplans_v2/floorplan_00644.jpg
#   inflating: floorplans_v2/floorplan_00653.jpg
#   inflating: floorplans_v2/floorplan_00634.jpg
#   inflating: floorplans_v2/floorplan_00654.jpg
#   inflating: floorplans_v2/floorplan_00631.jpg
#   inflating: floorplans_v2/floorplan_00633.jpg
#   inflating: floorplans_v2/floorplan_00638.jpg
#   inflating: floorplans_v2/floorplan_00626.jpg
#   inflating: floorplans_v2/floorplan_00628.jpg
#   inflating: floorplans_v2/floorplan_00630.jpg
#   inflating: floorplans_v2/floorplan_00627.jpg
#   inflating: floorplans_v2/floorplan_00632.jpg
#   inflating: floorplans_v2/floorplan_00622.jpg
#   inflating: floorplans_v2/floorplan_00629.jpg
#   inflating: floorplans_v2/floorplan_00642.jpg
#   inflating: floorplans_v2/floorplan_00619.jpg
#   inflating: floorplans_v2/floorplan_00635.jpg
#   inflating: floorplans_v2/floorplan_00637.jpg
#   inflating: floorplans_v2/floorplan_00621.jpg
#   inflating: floorplans_v2/floorplan_00620.jpg
#   inflating: floorplans_v2/floorplan_00614.jpg
#   inflating: floorplans_v2/floorplan_00616.jpg
#   inflating: floorplans_v2/floorplan_00617.jpg
#   inflating: floorplans_v2/floorplan_00615.jpg
#   inflating: floorplans_v2/floorplan_00613.jpg
#   inflating: floorplans_v2/floorplan_00625.jpg
#   inflating: floorplans_v2/floorplan_00623.jpg
#   inflating: floorplans_v2/floorplan_00611.jpg
#   inflating: floorplans_v2/floorplan_00609.jpg
#   inflating: floorplans_v2/floorplan_00607.jpg
#   inflating: floorplans_v2/floorplan_00604.jpg
#   inflating: floorplans_v2/floorplan_00600.jpg
#   inflating: floorplans_v2/floorplan_00624.jpg
#   inflating: floorplans_v2/floorplan_00618.jpg
#   inflating: floorplans_v2/floorplan_00612.jpg
#   inflating: floorplans_v2/floorplan_00602.jpg
#   inflating: floorplans_v2/floorplan_00605.jpg
#   inflating: floorplans_v2/floorplan_00606.jpg
#   inflating: floorplans_v2/floorplan_00603.jpg
#   inflating: floorplans_v2/floorplan_00601.jpg
#   inflating: floorplans_v2/floorplan_00597.jpg
#   inflating: floorplans_v2/floorplan_00608.jpg
#   inflating: floorplans_v2/floorplan_00599.jpg
#   inflating: floorplans_v2/floorplan_00594.jpg
#   inflating: floorplans_v2/floorplan_00595.jpg
#   inflating: floorplans_v2/floorplan_00610.jpg
#   inflating: floorplans_v2/floorplan_00591.jpg
#   inflating: floorplans_v2/floorplan_00590.jpg
#   inflating: floorplans_v2/floorplan_00592.jpg
#   inflating: floorplans_v2/floorplan_00586.jpg
#   inflating: floorplans_v2/floorplan_00589.jpg
#   inflating: floorplans_v2/floorplan_00596.jpg
#   inflating: floorplans_v2/floorplan_00585.jpg
#   inflating: floorplans_v2/floorplan_00593.jpg
#   inflating: floorplans_v2/floorplan_00587.jpg
#   inflating: floorplans_v2/floorplan_00588.jpg
#   inflating: floorplans_v2/floorplan_00598.jpg
#   inflating: floorplans_v2/floorplan_00578.jpg
#   inflating: floorplans_v2/floorplan_00584.jpg
#   inflating: floorplans_v2/floorplan_00581.jpg
#   inflating: floorplans_v2/floorplan_00579.jpg
#   inflating: floorplans_v2/floorplan_00583.jpg
#   inflating: floorplans_v2/floorplan_00577.jpg
#   inflating: floorplans_v2/floorplan_00582.jpg
#   inflating: floorplans_v2/floorplan_00576.jpg
#   inflating: floorplans_v2/floorplan_00580.jpg
#   inflating: floorplans_v2/floorplan_00575.jpg
#   inflating: floorplans_v2/floorplan_00573.jpg
#   inflating: floorplans_v2/floorplan_00572.jpg
#   inflating: floorplans_v2/floorplan_00570.jpg
#   inflating: floorplans_v2/floorplan_00568.jpg
#   inflating: floorplans_v2/floorplan_00574.jpg
#   inflating: floorplans_v2/floorplan_00565.jpg
#   inflating: floorplans_v2/floorplan_00571.jpg
#   inflating: floorplans_v2/floorplan_00559.jpg
#   inflating: floorplans_v2/floorplan_00560.jpg
#   inflating: floorplans_v2/floorplan_00561.jpg
#   inflating: floorplans_v2/floorplan_00566.jpg
#   inflating: floorplans_v2/floorplan_00569.jpg
#   inflating: floorplans_v2/floorplan_00562.jpg
#   inflating: floorplans_v2/floorplan_00567.jpg
#   inflating: floorplans_v2/floorplan_00554.jpg
#   inflating: floorplans_v2/floorplan_00564.jpg
#   inflating: floorplans_v2/floorplan_00552.jpg
#   inflating: floorplans_v2/floorplan_00558.jpg
#   inflating: floorplans_v2/floorplan_00563.jpg
#   inflating: floorplans_v2/floorplan_00557.jpg
#   inflating: floorplans_v2/floorplan_00553.jpg
#   inflating: floorplans_v2/floorplan_00549.jpg
#   inflating: floorplans_v2/floorplan_00551.jpg
#   inflating: floorplans_v2/floorplan_00550.jpg
#   inflating: floorplans_v2/floorplan_00548.jpg
#   inflating: floorplans_v2/floorplan_00547.jpg
#   inflating: floorplans_v2/floorplan_00545.jpg
#   inflating: floorplans_v2/floorplan_00542.jpg
#   inflating: floorplans_v2/floorplan_00546.jpg
#   inflating: floorplans_v2/floorplan_00541.jpg
#   inflating: floorplans_v2/floorplan_00556.jpg
#   inflating: floorplans_v2/floorplan_00543.jpg
#   inflating: floorplans_v2/floorplan_00555.jpg
#   inflating: floorplans_v2/floorplan_00538.jpg
#   inflating: floorplans_v2/floorplan_00539.jpg
#   inflating: floorplans_v2/floorplan_00533.jpg
#   inflating: floorplans_v2/floorplan_00540.jpg
#   inflating: floorplans_v2/floorplan_00544.jpg
#   inflating: floorplans_v2/floorplan_00537.jpg
#   inflating: floorplans_v2/floorplan_00528.jpg
#   inflating: floorplans_v2/floorplan_00530.jpg
#   inflating: floorplans_v2/floorplan_00536.jpg
#   inflating: floorplans_v2/floorplan_00531.jpg
#   inflating: floorplans_v2/floorplan_00532.jpg
#   inflating: floorplans_v2/floorplan_00534.jpg
#   inflating: floorplans_v2/floorplan_00520.jpg
#   inflating: floorplans_v2/floorplan_00527.jpg
#   inflating: floorplans_v2/floorplan_00526.jpg
#   inflating: floorplans_v2/floorplan_00518.jpg
#   inflating: floorplans_v2/floorplan_00521.jpg
#   inflating: floorplans_v2/floorplan_00529.jpg
#   inflating: floorplans_v2/floorplan_00525.jpg
#   inflating: floorplans_v2/floorplan_00519.jpg
#   inflating: floorplans_v2/floorplan_00522.jpg
#   inflating: floorplans_v2/floorplan_00523.jpg
#   inflating: floorplans_v2/floorplan_00524.jpg
#   inflating: floorplans_v2/floorplan_00535.jpg
#   inflating: floorplans_v2/floorplan_00515.jpg
#   inflating: floorplans_v2/floorplan_00516.jpg
#   inflating: floorplans_v2/floorplan_00486.jpg
#   inflating: floorplans_v2/floorplan_00120.jpg
#   inflating: floorplans_v2/floorplan_00483.jpg
#   inflating: floorplans_v2/floorplan_00119.jpg
#   inflating: floorplans_v2/floorplan_00517.jpg
#   inflating: floorplans_v2/floorplan_00118.jpg
#   inflating: floorplans_v2/floorplan_00484.jpg
#   inflating: floorplans_v2/floorplan_00261.jpg
#   inflating: floorplans_v2/floorplan_00514.jpg
#   inflating: floorplans_v2/floorplan_00485.jpg
#   inflating: floorplans_v2/floorplan_00116.jpg
#   inflating: floorplans_v2/floorplan_00117.jpg
#   inflating: floorplans_v2/floorplan_00482.jpg
#   inflating: floorplans_v2/floorplan_00513.jpg
#   inflating: floorplans_v2/floorplan_00461.jpg
#   inflating: floorplans_v2/floorplan_00412.jpg
#   inflating: floorplans_v2/floorplan_00177.jpg
#   inflating: floorplans_v2/floorplan_00115.jpg
#   inflating: floorplans_v2/floorplan_00460.jpg
#   inflating: floorplans_v2/floorplan_00481.jpg
#   inflating: floorplans_v2/floorplan_00259.jpg
#   inflating: floorplans_v2/floorplan_00512.jpg
#   inflating: floorplans_v2/floorplan_00459.jpg
#   inflating: floorplans_v2/floorplan_00260.jpg
#   inflating: floorplans_v2/floorplan_00342.jpg
#   inflating: floorplans_v2/floorplan_00275.jpg
#   inflating: floorplans_v2/floorplan_00511.jpg
#   inflating: floorplans_v2/floorplan_00480.jpg
#   inflating: floorplans_v2/floorplan_00447.jpg
#   inflating: floorplans_v2/floorplan_00155.jpg
#   inflating: floorplans_v2/floorplan_00397.jpg
#   inflating: floorplans_v2/floorplan_00327.jpg
#   inflating: floorplans_v2/floorplan_00258.jpg
#   inflating: floorplans_v2/floorplan_00235.jpg
#   inflating: floorplans_v2/floorplan_00328.jpg
#   inflating: floorplans_v2/floorplan_00479.jpg
#   inflating: floorplans_v2/floorplan_00446.jpg
#   inflating: floorplans_v2/floorplan_00354.jpg
#   inflating: floorplans_v2/floorplan_00114.jpg
#   inflating: floorplans_v2/floorplan_00510.jpg
#   inflating: floorplans_v2/floorplan_00039.jpg
#   inflating: floorplans_v2/floorplan_00411.jpg
#   inflating: floorplans_v2/floorplan_00093.jpg
#   inflating: floorplans_v2/floorplan_00176.jpg
#   inflating: floorplans_v2/floorplan_00246.jpg
#   inflating: floorplans_v2/floorplan_00341.jpg
#   inflating: floorplans_v2/floorplan_00410.jpg
#   inflating: floorplans_v2/floorplan_00287.jpg
#   inflating: floorplans_v2/floorplan_00069.jpg
#   inflating: floorplans_v2/floorplan_00445.jpg
#   inflating: floorplans_v2/floorplan_00257.jpg
#   inflating: floorplans_v2/floorplan_00154.jpg
#   inflating: floorplans_v2/floorplan_00175.jpg
#   inflating: floorplans_v2/floorplan_00070.jpg
#   inflating: floorplans_v2/floorplan_00384.jpg
#   inflating: floorplans_v2/floorplan_00340.jpg
#   inflating: floorplans_v2/floorplan_00498.jpg
#   inflating: floorplans_v2/floorplan_00274.jpg
#   inflating: floorplans_v2/floorplan_00153.jpg
#   inflating: floorplans_v2/floorplan_00478.jpg
#   inflating: floorplans_v2/floorplan_00003.jpg
#   inflating: floorplans_v2/floorplan_00509.jpg
#   inflating: floorplans_v2/floorplan_00234.jpg
#   inflating: floorplans_v2/floorplan_00353.jpg
#   inflating: floorplans_v2/floorplan_00458.jpg
#   inflating: floorplans_v2/floorplan_00339.jpg
#   inflating: floorplans_v2/floorplan_00396.jpg
#   inflating: floorplans_v2/floorplan_00002.jpg
#   inflating: floorplans_v2/floorplan_00001.jpg
#   inflating: floorplans_v2/floorplan_00222.jpg
#   inflating: floorplans_v2/floorplan_00038.jpg
#   inflating: floorplans_v2/floorplan_00000.jpg
#   inflating: floorplans_v2/floorplan_00326.jpg
#   inflating: floorplans_v2/floorplan_00113.jpg
#   inflating: floorplans_v2/floorplan_00298.jpg
#   inflating: floorplans_v2/floorplan_00189.jpg
#   inflating: floorplans_v2/floorplan_00508.jpg
#   inflating: floorplans_v2/floorplan_00068.jpg
#   inflating: floorplans_v2/floorplan_00497.jpg
#   inflating: floorplans_v2/floorplan_00080.jpg
#   inflating: floorplans_v2/floorplan_00092.jpg
#   inflating: floorplans_v2/floorplan_00273.jpg
#   inflating: floorplans_v2/floorplan_00383.jpg
#   inflating: floorplans_v2/floorplan_00058.jpg
#   inflating: floorplans_v2/floorplan_00409.jpg
#   inflating: floorplans_v2/floorplan_00112.jpg
#   inflating: floorplans_v2/floorplan_00286.jpg
#   inflating: floorplans_v2/floorplan_00233.jpg
#   inflating: floorplans_v2/floorplan_00256.jpg
#   inflating: floorplans_v2/floorplan_00174.jpg
#   inflating: floorplans_v2/floorplan_00352.jpg
#   inflating: floorplans_v2/floorplan_00130.jpg
#   inflating: floorplans_v2/floorplan_00434.jpg
#   inflating: floorplans_v2/floorplan_00338.jpg
#   inflating: floorplans_v2/floorplan_00140.jpg
#   inflating: floorplans_v2/floorplan_00188.jpg
#   inflating: floorplans_v2/floorplan_00433.jpg
#   inflating: floorplans_v2/floorplan_00364.jpg
#   inflating: floorplans_v2/floorplan_00477.jpg
#   inflating: floorplans_v2/floorplan_00325.jpg
#   inflating: floorplans_v2/floorplan_00297.jpg
#   inflating: floorplans_v2/floorplan_00027.jpg
#   inflating: floorplans_v2/floorplan_00457.jpg
#   inflating: floorplans_v2/floorplan_00245.jpg
#   inflating: floorplans_v2/floorplan_00152.jpg
#   inflating: floorplans_v2/floorplan_00232.jpg
#   inflating: floorplans_v2/floorplan_00272.jpg
#   inflating: floorplans_v2/floorplan_00382.jpg
#   inflating: floorplans_v2/floorplan_00271.jpg
#   inflating: floorplans_v2/floorplan_00444.jpg
#   inflating: floorplans_v2/floorplan_00091.jpg
#   inflating: floorplans_v2/floorplan_00199.jpg
#   inflating: floorplans_v2/floorplan_00363.jpg
#   inflating: floorplans_v2/floorplan_00476.jpg
#   inflating: floorplans_v2/floorplan_00443.jpg
#   inflating: floorplans_v2/floorplan_00408.jpg
#   inflating: floorplans_v2/floorplan_00037.jpg
#   inflating: floorplans_v2/floorplan_00198.jpg
#   inflating: floorplans_v2/floorplan_00373.jpg
#   inflating: floorplans_v2/floorplan_00079.jpg
#   inflating: floorplans_v2/floorplan_00220.jpg
#   inflating: floorplans_v2/floorplan_00285.jpg
#   inflating: floorplans_v2/floorplan_00187.jpg
#   inflating: floorplans_v2/floorplan_00067.jpg
#   inflating: floorplans_v2/floorplan_00090.jpg
#   inflating: floorplans_v2/floorplan_00221.jpg
#   inflating: floorplans_v2/floorplan_00507.jpg
#   inflating: floorplans_v2/floorplan_00324.jpg
#   inflating: floorplans_v2/floorplan_00111.jpg
#   inflating: floorplans_v2/floorplan_00496.jpg
#   inflating: floorplans_v2/floorplan_00296.jpg
#   inflating: floorplans_v2/floorplan_00151.jpg
#   inflating: floorplans_v2/floorplan_00139.jpg
#   inflating: floorplans_v2/floorplan_00057.jpg
#   inflating: floorplans_v2/floorplan_00315.jpg
#   inflating: floorplans_v2/floorplan_00173.jpg
#   inflating: floorplans_v2/floorplan_00337.jpg
#   inflating: floorplans_v2/floorplan_00129.jpg
#   inflating: floorplans_v2/floorplan_00395.jpg
#   inflating: floorplans_v2/floorplan_00255.jpg
#   inflating: floorplans_v2/floorplan_00351.jpg
#   inflating: floorplans_v2/floorplan_00394.jpg
#   inflating: floorplans_v2/floorplan_00270.jpg
#   inflating: floorplans_v2/floorplan_00422.jpg
#   inflating: floorplans_v2/floorplan_00048.jpg
#   inflating: floorplans_v2/floorplan_00231.jpg
#   inflating: floorplans_v2/floorplan_00036.jpg
#   inflating: floorplans_v2/floorplan_00420.jpg
#   inflating: floorplans_v2/floorplan_00381.jpg
#   inflating: floorplans_v2/floorplan_00056.jpg
#   inflating: floorplans_v2/floorplan_00243.jpg
#   inflating: floorplans_v2/floorplan_00244.jpg
#   inflating: floorplans_v2/floorplan_00026.jpg
#   inflating: floorplans_v2/floorplan_00254.jpg
#   inflating: floorplans_v2/floorplan_00197.jpg
#   inflating: floorplans_v2/floorplan_00284.jpg
#   inflating: floorplans_v2/floorplan_00295.jpg
#   inflating: floorplans_v2/floorplan_00207.jpg
#   inflating: floorplans_v2/floorplan_00432.jpg
#   inflating: floorplans_v2/floorplan_00314.jpg
#   inflating: floorplans_v2/floorplan_00066.jpg
#   inflating: floorplans_v2/floorplan_00506.jpg
#   inflating: floorplans_v2/floorplan_00306.jpg
#   inflating: floorplans_v2/floorplan_00078.jpg
#   inflating: floorplans_v2/floorplan_00102.jpg
#   inflating: floorplans_v2/floorplan_00442.jpg
#   inflating: floorplans_v2/floorplan_00431.jpg
#   inflating: floorplans_v2/floorplan_00475.jpg
#   inflating: floorplans_v2/floorplan_00372.jpg
#   inflating: floorplans_v2/floorplan_00350.jpg
#   inflating: floorplans_v2/floorplan_00456.jpg
#   inflating: floorplans_v2/floorplan_00421.jpg
#   inflating: floorplans_v2/floorplan_00336.jpg
#   inflating: floorplans_v2/floorplan_00172.jpg
#   inflating: floorplans_v2/floorplan_00186.jpg
#   inflating: floorplans_v2/floorplan_00407.jpg
#   inflating: floorplans_v2/floorplan_00138.jpg
#   inflating: floorplans_v2/floorplan_00128.jpg
#   inflating: floorplans_v2/floorplan_00149.jpg
#   inflating: floorplans_v2/floorplan_00150.jpg
#   inflating: floorplans_v2/floorplan_00495.jpg
#   inflating: floorplans_v2/floorplan_00269.jpg
#   inflating: floorplans_v2/floorplan_00025.jpg
#   inflating: floorplans_v2/floorplan_00362.jpg
#   inflating: floorplans_v2/floorplan_00455.jpg
#   inflating: floorplans_v2/floorplan_00006.jpg
#   inflating: floorplans_v2/floorplan_00110.jpg
#   inflating: floorplans_v2/floorplan_00393.jpg
#   inflating: floorplans_v2/floorplan_00322.jpg
#   inflating: floorplans_v2/floorplan_00047.jpg
#   inflating: floorplans_v2/floorplan_00035.jpg
#   inflating: floorplans_v2/floorplan_00219.jpg
#   inflating: floorplans_v2/floorplan_00323.jpg
#   inflating: floorplans_v2/floorplan_00089.jpg
#   inflating: floorplans_v2/floorplan_00229.jpg
#   inflating: floorplans_v2/floorplan_00380.jpg
#   inflating: floorplans_v2/floorplan_00505.jpg
#   inflating: floorplans_v2/floorplan_00230.jpg
#   inflating: floorplans_v2/floorplan_00283.jpg
#   inflating: floorplans_v2/floorplan_00371.jpg
#   inflating: floorplans_v2/floorplan_00206.jpg
#   inflating: floorplans_v2/floorplan_00419.jpg
#   inflating: floorplans_v2/floorplan_00065.jpg
#   inflating: floorplans_v2/floorplan_00253.jpg
#   inflating: floorplans_v2/floorplan_00087.jpg
#   inflating: floorplans_v2/floorplan_00349.jpg
#   inflating: floorplans_v2/floorplan_00242.jpg
#   inflating: floorplans_v2/floorplan_00196.jpg
#   inflating: floorplans_v2/floorplan_00171.jpg
#   inflating: floorplans_v2/floorplan_00024.jpg
#   inflating: floorplans_v2/floorplan_00313.jpg
#   inflating: floorplans_v2/floorplan_00494.jpg
#   inflating: floorplans_v2/floorplan_00406.jpg
#   inflating: floorplans_v2/floorplan_00101.jpg
#   inflating: floorplans_v2/floorplan_00148.jpg
#   inflating: floorplans_v2/floorplan_00430.jpg
#   inflating: floorplans_v2/floorplan_00088.jpg
#   inflating: floorplans_v2/floorplan_00218.jpg
#   inflating: floorplans_v2/floorplan_00361.jpg
#   inflating: floorplans_v2/floorplan_00055.jpg
#   inflating: floorplans_v2/floorplan_00441.jpg
#   inflating: floorplans_v2/floorplan_00185.jpg
#   inflating: floorplans_v2/floorplan_00109.jpg
#   inflating: floorplans_v2/floorplan_00335.jpg
#   inflating: floorplans_v2/floorplan_00474.jpg
#   inflating: floorplans_v2/floorplan_00268.jpg
#   inflating: floorplans_v2/floorplan_00294.jpg
#   inflating: floorplans_v2/floorplan_00163.jpg
#   inflating: floorplans_v2/floorplan_00034.jpg
#   inflating: floorplans_v2/floorplan_00127.jpg
#   inflating: floorplans_v2/floorplan_00305.jpg
#   inflating: floorplans_v2/floorplan_00077.jpg
#   inflating: floorplans_v2/floorplan_00046.jpg
#   inflating: floorplans_v2/floorplan_00392.jpg
#   inflating: floorplans_v2/floorplan_00217.jpg
#   inflating: floorplans_v2/floorplan_00379.jpg
#   inflating: floorplans_v2/floorplan_00033.jpg
#   inflating: floorplans_v2/floorplan_00252.jpg
#   inflating: floorplans_v2/floorplan_00016.jpg
#   inflating: floorplans_v2/floorplan_00370.jpg
#   inflating: floorplans_v2/floorplan_00454.jpg
#   inflating: floorplans_v2/floorplan_00005.jpg
#   inflating: floorplans_v2/floorplan_00473.jpg
#   inflating: floorplans_v2/floorplan_00228.jpg
#   inflating: floorplans_v2/floorplan_00205.jpg
#   inflating: floorplans_v2/floorplan_00493.jpg
#   inflating: floorplans_v2/floorplan_00064.jpg
#   inflating: floorplans_v2/floorplan_00137.jpg
#   inflating: floorplans_v2/floorplan_00282.jpg
#   inflating: floorplans_v2/floorplan_00405.jpg
#   inflating: floorplans_v2/floorplan_00403.jpg
#   inflating: floorplans_v2/floorplan_00184.jpg
#   inflating: floorplans_v2/floorplan_00086.jpg
#   inflating: floorplans_v2/floorplan_00429.jpg
#   inflating: floorplans_v2/floorplan_00054.jpg
#   inflating: floorplans_v2/floorplan_00504.jpg
#   inflating: floorplans_v2/floorplan_00321.jpg
#   inflating: floorplans_v2/floorplan_00147.jpg
#   inflating: floorplans_v2/floorplan_00126.jpg
#   inflating: floorplans_v2/floorplan_00136.jpg
#   inflating: floorplans_v2/floorplan_00360.jpg
#   inflating: floorplans_v2/floorplan_00334.jpg
#   inflating: floorplans_v2/floorplan_00099.jpg
#   inflating: floorplans_v2/floorplan_00312.jpg
#   inflating: floorplans_v2/floorplan_00108.jpg
#   inflating: floorplans_v2/floorplan_00467.jpg
#   inflating: floorplans_v2/floorplan_00170.jpg
#   inflating: floorplans_v2/floorplan_00304.jpg
#   inflating: floorplans_v2/floorplan_00169.jpg
#   inflating: floorplans_v2/floorplan_00076.jpg
#   inflating: floorplans_v2/floorplan_00195.jpg
#   inflating: floorplans_v2/floorplan_00241.jpg
#   inflating: floorplans_v2/floorplan_00293.jpg
#   inflating: floorplans_v2/floorplan_00348.jpg
#   inflating: floorplans_v2/floorplan_00023.jpg
#   inflating: floorplans_v2/floorplan_00391.jpg
#   inflating: floorplans_v2/floorplan_00162.jpg
#   inflating: floorplans_v2/floorplan_00100.jpg
#   inflating: floorplans_v2/floorplan_00390.jpg
#   inflating: floorplans_v2/floorplan_00267.jpg
#   inflating: floorplans_v2/floorplan_00492.jpg
#   inflating: floorplans_v2/floorplan_00369.jpg
#   inflating: floorplans_v2/floorplan_00440.jpg
#   inflating: floorplans_v2/floorplan_00453.jpg
#   inflating: floorplans_v2/floorplan_00216.jpg
#   inflating: floorplans_v2/floorplan_00418.jpg
#   inflating: floorplans_v2/floorplan_00015.jpg
#   inflating: floorplans_v2/floorplan_00359.jpg
#   inflating: floorplans_v2/floorplan_00227.jpg
#   inflating: floorplans_v2/floorplan_00266.jpg
#   inflating: floorplans_v2/floorplan_00045.jpg
#   inflating: floorplans_v2/floorplan_00503.jpg
#   inflating: floorplans_v2/floorplan_00240.jpg
#   inflating: floorplans_v2/floorplan_00439.jpg
#   inflating: floorplans_v2/floorplan_00022.jpg
#   inflating: floorplans_v2/floorplan_00085.jpg
#   inflating: floorplans_v2/floorplan_00320.jpg
#   inflating: floorplans_v2/floorplan_00168.jpg
#   inflating: floorplans_v2/floorplan_00292.jpg
#   inflating: floorplans_v2/floorplan_00333.jpg
#   inflating: floorplans_v2/floorplan_00135.jpg
#   inflating: floorplans_v2/floorplan_00404.jpg
#   inflating: floorplans_v2/floorplan_00402.jpg
#   inflating: floorplans_v2/floorplan_00251.jpg
#   inflating: floorplans_v2/floorplan_00472.jpg
#   inflating: floorplans_v2/floorplan_00303.jpg
#   inflating: floorplans_v2/floorplan_00428.jpg
#   inflating: floorplans_v2/floorplan_00098.jpg
#   inflating: floorplans_v2/floorplan_00107.jpg
#   inflating: floorplans_v2/floorplan_00063.jpg
#   inflating: floorplans_v2/floorplan_00378.jpg
#   inflating: floorplans_v2/floorplan_00466.jpg
#   inflating: floorplans_v2/floorplan_00125.jpg
#   inflating: floorplans_v2/floorplan_00146.jpg
#   inflating: floorplans_v2/floorplan_00347.jpg
#   inflating: floorplans_v2/floorplan_00280.jpg
#   inflating: floorplans_v2/floorplan_00053.jpg
#   inflating: floorplans_v2/floorplan_00004.jpg
#   inflating: floorplans_v2/floorplan_00452.jpg
#   inflating: floorplans_v2/floorplan_00044.jpg
#   inflating: floorplans_v2/floorplan_00204.jpg
#   inflating: floorplans_v2/floorplan_00438.jpg
#   inflating: floorplans_v2/floorplan_00010.jpg
#   inflating: floorplans_v2/floorplan_00417.jpg
#   inflating: floorplans_v2/floorplan_00311.jpg
#   inflating: floorplans_v2/floorplan_00161.jpg
#   inflating: floorplans_v2/floorplan_00032.jpg
#   inflating: floorplans_v2/floorplan_00239.jpg
#   inflating: floorplans_v2/floorplan_00194.jpg
#   inflating: floorplans_v2/floorplan_00183.jpg
#   inflating: floorplans_v2/floorplan_00075.jpg
#   inflating: floorplans_v2/floorplan_00281.jpg
#   inflating: floorplans_v2/floorplan_00052.jpg
#   inflating: floorplans_v2/floorplan_00377.jpg
#   inflating: floorplans_v2/floorplan_00471.jpg
#   inflating: floorplans_v2/floorplan_00193.jpg
#   inflating: floorplans_v2/floorplan_00226.jpg
#   inflating: floorplans_v2/floorplan_00124.jpg
#   inflating: floorplans_v2/floorplan_00416.jpg
#   inflating: floorplans_v2/floorplan_00211.jpg
#   inflating: floorplans_v2/floorplan_00145.jpg
#   inflating: floorplans_v2/floorplan_00389.jpg
#   inflating: floorplans_v2/floorplan_00346.jpg
#   inflating: floorplans_v2/floorplan_00215.jpg
#   inflating: floorplans_v2/floorplan_00160.jpg
#   inflating: floorplans_v2/floorplan_00427.jpg
#   inflating: floorplans_v2/floorplan_00332.jpg
#   inflating: floorplans_v2/floorplan_00250.jpg
#   inflating: floorplans_v2/floorplan_00106.jpg
#   inflating: floorplans_v2/floorplan_00310.jpg
#   inflating: floorplans_v2/floorplan_00465.jpg
#   inflating: floorplans_v2/floorplan_00302.jpg
#   inflating: floorplans_v2/floorplan_00291.jpg
#   inflating: floorplans_v2/floorplan_00014.jpg
#   inflating: floorplans_v2/floorplan_00084.jpg
#   inflating: floorplans_v2/floorplan_00062.jpg
#   inflating: floorplans_v2/floorplan_00388.jpg
#   inflating: floorplans_v2/floorplan_00182.jpg
#   inflating: floorplans_v2/floorplan_00074.jpg
#   inflating: floorplans_v2/floorplan_00167.jpg
#   inflating: floorplans_v2/floorplan_00097.jpg
#   inflating: floorplans_v2/floorplan_00279.jpg
#   inflating: floorplans_v2/floorplan_00319.jpg
#   inflating: floorplans_v2/floorplan_00451.jpg
#   inflating: floorplans_v2/floorplan_00203.jpg
#   inflating: floorplans_v2/floorplan_00368.jpg
#   inflating: floorplans_v2/floorplan_00502.jpg
#   inflating: floorplans_v2/floorplan_00358.jpg
#   inflating: floorplans_v2/floorplan_00021.jpg
#   inflating: floorplans_v2/floorplan_00043.jpg
#   inflating: floorplans_v2/floorplan_00401.jpg
#   inflating: floorplans_v2/floorplan_00249.jpg
#   inflating: floorplans_v2/floorplan_00491.jpg
#   inflating: floorplans_v2/floorplan_00367.jpg
#   inflating: floorplans_v2/floorplan_00134.jpg
#   inflating: floorplans_v2/floorplan_00009.jpg
#   inflating: floorplans_v2/floorplan_00013.jpg
#   inflating: floorplans_v2/floorplan_00265.jpg
#   inflating: floorplans_v2/floorplan_00031.jpg
#   inflating: floorplans_v2/floorplan_00042.jpg
#   inflating: floorplans_v2/floorplan_00376.jpg
#   inflating: floorplans_v2/floorplan_00210.jpg
#   inflating: floorplans_v2/floorplan_00238.jpg
#   inflating: floorplans_v2/floorplan_00426.jpg
#   inflating: floorplans_v2/floorplan_00158.jpg
#   inflating: floorplans_v2/floorplan_00450.jpg
#   inflating: floorplans_v2/floorplan_00202.jpg
#   inflating: floorplans_v2/floorplan_00225.jpg
#   inflating: floorplans_v2/floorplan_00166.jpg
#   inflating: floorplans_v2/floorplan_00096.jpg
#   inflating: floorplans_v2/floorplan_00030.jpg
#   inflating: floorplans_v2/floorplan_00501.jpg
#   inflating: floorplans_v2/floorplan_00214.jpg
#   inflating: floorplans_v2/floorplan_00105.jpg
#   inflating: floorplans_v2/floorplan_00061.jpg
#   inflating: floorplans_v2/floorplan_00400.jpg
#   inflating: floorplans_v2/floorplan_00331.jpg
#   inflating: floorplans_v2/floorplan_00437.jpg
#   inflating: floorplans_v2/floorplan_00192.jpg
#   inflating: floorplans_v2/floorplan_00470.jpg
#   inflating: floorplans_v2/floorplan_00318.jpg
#   inflating: floorplans_v2/floorplan_00345.jpg
#   inflating: floorplans_v2/floorplan_00301.jpg
#   inflating: floorplans_v2/floorplan_00290.jpg
#   inflating: floorplans_v2/floorplan_00020.jpg
#   inflating: floorplans_v2/floorplan_00181.jpg
#   inflating: floorplans_v2/floorplan_00133.jpg
#   inflating: floorplans_v2/floorplan_00464.jpg
#   inflating: floorplans_v2/floorplan_00083.jpg
#   inflating: floorplans_v2/floorplan_00159.jpg
#   inflating: floorplans_v2/floorplan_00309.jpg
#   inflating: floorplans_v2/floorplan_00278.jpg
#   inflating: floorplans_v2/floorplan_00073.jpg
#   inflating: floorplans_v2/floorplan_00387.jpg
#   inflating: floorplans_v2/floorplan_00264.jpg
#   inflating: floorplans_v2/floorplan_00123.jpg
#   inflating: floorplans_v2/floorplan_00308.jpg
#   inflating: floorplans_v2/floorplan_00490.jpg
#   inflating: floorplans_v2/floorplan_00415.jpg
#   inflating: floorplans_v2/floorplan_00300.jpg
#   inflating: floorplans_v2/floorplan_00144.jpg
#   inflating: floorplans_v2/floorplan_00500.jpg
#   inflating: floorplans_v2/floorplan_00463.jpg
#   inflating: floorplans_v2/floorplan_00019.jpg
#   inflating: floorplans_v2/floorplan_00425.jpg
#   inflating: floorplans_v2/floorplan_00263.jpg
#   inflating: floorplans_v2/floorplan_00029.jpg
#   inflating: floorplans_v2/floorplan_00213.jpg
#   inflating: floorplans_v2/floorplan_00489.jpg
#   inflating: floorplans_v2/floorplan_00357.jpg
#   inflating: floorplans_v2/floorplan_00122.jpg
#   inflating: floorplans_v2/floorplan_00132.jpg
#   inflating: floorplans_v2/floorplan_00041.jpg
#   inflating: floorplans_v2/floorplan_00142.jpg
#   inflating: floorplans_v2/floorplan_00051.jpg
#   inflating: floorplans_v2/floorplan_00060.jpg
#   inflating: floorplans_v2/floorplan_00201.jpg
#   inflating: floorplans_v2/floorplan_00330.jpg
#   inflating: floorplans_v2/floorplan_00157.jpg
#   inflating: floorplans_v2/floorplan_00012.jpg
#   inflating: floorplans_v2/floorplan_00050.jpg
#   inflating: floorplans_v2/floorplan_00191.jpg
#   inflating: floorplans_v2/floorplan_00488.jpg
#   inflating: floorplans_v2/floorplan_00248.jpg
#   inflating: floorplans_v2/floorplan_00209.jpg
#   inflating: floorplans_v2/floorplan_00449.jpg
#   inflating: floorplans_v2/floorplan_00289.jpg
#   inflating: floorplans_v2/floorplan_00008.jpg
#   inflating: floorplans_v2/floorplan_00414.jpg
#   inflating: floorplans_v2/floorplan_00436.jpg
#   inflating: floorplans_v2/floorplan_00082.jpg
#   inflating: floorplans_v2/floorplan_00356.jpg
#   inflating: floorplans_v2/floorplan_00344.jpg
#   inflating: floorplans_v2/floorplan_00095.jpg
#   inflating: floorplans_v2/floorplan_00386.jpg
#   inflating: floorplans_v2/floorplan_00180.jpg
#   inflating: floorplans_v2/floorplan_00143.jpg
#   inflating: floorplans_v2/floorplan_00277.jpg
#   inflating: floorplans_v2/floorplan_00375.jpg
#   inflating: floorplans_v2/floorplan_00237.jpg
#   inflating: floorplans_v2/floorplan_00424.jpg
#   inflating: floorplans_v2/floorplan_00399.jpg
#   inflating: floorplans_v2/floorplan_00317.jpg
#   inflating: floorplans_v2/floorplan_00469.jpg
#   inflating: floorplans_v2/floorplan_00165.jpg
#   inflating: floorplans_v2/floorplan_00104.jpg
#   inflating: floorplans_v2/floorplan_00468.jpg
#   inflating: floorplans_v2/floorplan_00366.jpg
#   inflating: floorplans_v2/floorplan_00200.jpg
#   inflating: floorplans_v2/floorplan_00179.jpg
#   inflating: floorplans_v2/floorplan_00040.jpg
#   inflating: floorplans_v2/floorplan_00224.jpg
#   inflating: floorplans_v2/floorplan_00208.jpg
#   inflating: floorplans_v2/floorplan_00072.jpg
#   inflating: floorplans_v2/floorplan_00462.jpg
#   inflating: floorplans_v2/floorplan_00081.jpg
#   inflating: floorplans_v2/floorplan_00223.jpg
#   inflating: floorplans_v2/floorplan_00178.jpg
#   inflating: floorplans_v2/floorplan_00247.jpg
#   inflating: floorplans_v2/floorplan_00448.jpg
#   inflating: floorplans_v2/floorplan_00355.jpg
#   inflating: floorplans_v2/floorplan_00156.jpg
#   inflating: floorplans_v2/floorplan_00190.jpg
#   inflating: floorplans_v2/floorplan_00262.jpg
#   inflating: floorplans_v2/floorplan_00307.jpg
#   inflating: floorplans_v2/floorplan_00487.jpg
#   inflating: floorplans_v2/floorplan_00299.jpg
#   inflating: floorplans_v2/floorplan_00343.jpg
#   inflating: floorplans_v2/floorplan_00094.jpg
#   inflating: floorplans_v2/floorplan_00212.jpg
#   inflating: floorplans_v2/floorplan_00288.jpg
#   inflating: floorplans_v2/floorplan_00236.jpg
#   inflating: floorplans_v2/floorplan_00385.jpg
#   inflating: floorplans_v2/floorplan_00011.jpg
#   inflating: floorplans_v2/floorplan_00007.jpg
#   inflating: floorplans_v2/floorplan_00423.jpg
#   inflating: floorplans_v2/floorplan_00499.jpg
#   inflating: floorplans_v2/floorplan_00164.jpg
#   inflating: floorplans_v2/floorplan_00329.jpg
#   inflating: floorplans_v2/floorplan_00131.jpg
#   inflating: floorplans_v2/floorplan_00365.jpg
#   inflating: floorplans_v2/floorplan_00049.jpg
#   inflating: floorplans_v2/floorplan_00018.jpg
#   inflating: floorplans_v2/floorplan_00141.jpg
#   inflating: floorplans_v2/floorplan_00276.jpg
#   inflating: floorplans_v2/floorplan_00059.jpg
#   inflating: floorplans_v2/floorplan_00028.jpg
#   inflating: floorplans_v2/floorplan_00017.jpg
#   inflating: floorplans_v2/floorplan_00398.jpg
#   inflating: floorplans_v2/floorplan_00103.jpg
#   inflating: floorplans_v2/floorplan_00316.jpg
#   inflating: floorplans_v2/floorplan_00435.jpg
#   inflating: floorplans_v2/floorplan_00374.jpg
#   inflating: floorplans_v2/floorplan_00071.jpg
#   inflating: floorplans_v2/floorplan_00413.jpg
#   inflating: floorplans_v2/floorplan_00121.jpg
#  extracting: receipts_sample-20260102T154712Z-3-001.zip
# Zip file extracted to 'receipt_images' directory.

# %% [markdown]
# ## Model Architecture and Flow Matching Logic
#
# This section defines the core components of our generative model: the `ConditionalUNet` architecture, which is a neural network designed for image generation tasks, and the `FlowMatching` class, which implements the training and sampling logic for flow-based generative models. It also includes our custom `ReceiptDataset` to handle loading and transforming the image data.
#
# ### SinusoidalPositionEmbeddings
# This class creates sinusoidal positional embeddings for time steps. In generative models like Flow Matching, these embeddings help the network understand the 'progress' of the generation process (from noise to data) by providing a unique, continuous representation for each time step.
#
# ### Block
# The `Block` class represents a fundamental building block of the U-Net architecture. It consists of convolutional layers, batch normalization, and ReLU activations. It also integrates time embeddings, allowing the model to condition its output on the current time step in the flow. The `transform` layer handles downsampling (Conv2d with stride 2) or upsampling (ConvTranspose2d) within the U-Net.
#
# ### ConditionalUNet
# The `ConditionalUNet` is the main neural network architecture. It's a U-Net variant that processes images and is 'conditional' because it takes both the image, the current time step (`t`), and a class label (though here we only have one class) as input. This allows the model to learn to generate specific types of images. It consists of a series of `Block`s for downsampling (`downs`) and upsampling (`ups`), with skip connections (residuals) to preserve detail.
#
# ### FlowMatching
# This class encapsulates the core logic of the Flow Matching generative process. Unlike diffusion models that iteratively add and remove noise, Flow Matching learns a continuous-time vector field that smoothly transports a simple prior distribution (e.g., Gaussian noise, `x_0`) to a complex target distribution (the real data, `x_1`).
#
# -   **`compute_loss`**: Calculates the loss for training. It samples `x_0` (noise), `x_1` (real data), and a random time `t`. It then computes an intermediate point `x_t` on the straight line path between `x_0` and `x_1`, and asks the model to predict the velocity vector (`v_target`) that points from `x_0` to `x_1`. The loss is the mean squared error between the model's predicted velocity (`v_pred`) and the true target velocity.
# -   **`sample`**: Implements an Euler ODE solver for generating new images. Starting from random noise (`x_0` at `t=0`), it iteratively updates the image by following the velocity field predicted by the trained `ConditionalUNet`. This process effectively traces a path from noise to a generated image (`x_1` at `t=1`).
#
# ### ReceiptDataset
# This custom `torch.utils.data.Dataset` class is responsible for loading our receipt images. It reads image files from the specified directory, converts them to grayscale, resizes them to the model's input dimensions, and transforms them into PyTorch tensors. Since we are only generating receipts, it assigns a single class label (0) to all images.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision.utils import make_grid
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import random
import os
from PIL import Image
import glob

# Re-define device and HPARAMS as they were not in the current execution context
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

HPARAMS = {
    "img_size": 256,
    "inference_steps": 100,
    "batch_size": 32,
    "lr": 1e-4,
    "epochs": 50,
    "channels": 1,
    "num_classes": 1 # Updated for receipts only
}

# Re-define model architecture (ConditionalUNet, Block, SinusoidalPositionEmbeddings)
class SinusoidalPositionEmbeddings(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim
    def forward(self, time):
        device = time.device
        half_dim = self.dim // 2
        embeddings = np.log(10000) / (half_dim - 1)
        embeddings = torch.exp(torch.arange(half_dim, device=device) * -embeddings)
        embeddings = time[:, None] * embeddings[None, :]
        embeddings = torch.cat((embeddings.sin(), embeddings.cos()), dim=-1)
        return embeddings

class Block(nn.Module):
    def __init__(self, in_ch, out_ch, time_emb_dim, up=False):
        super().__init__()
        self.time_mlp = nn.Linear(time_emb_dim, out_ch)
        if up:
            self.conv1 = nn.Conv2d(2*in_ch, out_ch, 3, padding=1)
            self.transform = nn.ConvTranspose2d(out_ch, out_ch, 4, 2, 1)
        else:
            self.conv1 = nn.Conv2d(in_ch, out_ch, 3, padding=1)
            self.transform = nn.Conv2d(out_ch, out_ch, 4, 2, 1)
        self.conv2 = nn.Conv2d(out_ch, out_ch, 3, padding=1)
        self.bnorm1 = nn.BatchNorm2d(out_ch)
        self.bnorm2 = nn.BatchNorm2d(out_ch)
        self.relu = nn.ReLU()

    def forward(self, x, t):
        h = self.bnorm1(self.relu(self.conv1(x)))
        time_emb = self.relu(self.time_mlp(t))
        time_emb = time_emb[(..., ) + (None, ) * 2]
        h = h + time_emb
        h = self.bnorm2(self.relu(self.conv2(h)))
        return self.transform(h)

class ConditionalUNet(nn.Module):
    def __init__(self):
        super().__init__()
        img_channels = HPARAMS["channels"]
        down_channels = (32, 64, 128)
        up_channels = (128, 64, 32)
        out_dim = img_channels
        time_emb_dim = 32
        classes = HPARAMS["num_classes"]

        self.time_mlp = nn.Sequential(
            SinusoidalPositionEmbeddings(time_emb_dim),
            nn.Linear(time_emb_dim, time_emb_dim),
            nn.ReLU()
        )
        self.class_emb = nn.Embedding(classes, time_emb_dim)
        self.conv0 = nn.Conv2d(img_channels, down_channels[0], 3, padding=1)
        self.downs = nn.ModuleList([Block(down_channels[i], down_channels[i+1], time_emb_dim) for i in range(len(down_channels)-1)])
        self.ups = nn.ModuleList([Block(up_channels[i], up_channels[i+1], time_emb_dim, up=True) for i in range(len(up_channels)-1)])
        self.output = nn.Conv2d(up_channels[-1], out_dim, 1)

    def forward(self, x, t_float, class_label):
        t = self.time_mlp(t_float)
        c = self.class_emb(class_label)
        t = t + c
        x = self.conv0(x)
        residuals = []
        for down in self.downs:
            x = down(x, t)
            residuals.append(x)
        for up in self.ups:
            residual = residuals.pop()
            x = torch.cat((x, residual), dim=1)
            x = up(x, t)
        return self.output(x)

# Re-define FlowMatching logic
class FlowMatching:
    def __init__(self):
        pass

    def compute_loss(self, model, x_1, labels):
        b = x_1.shape[0]
        x_0 = torch.randn_like(x_1)
        t = torch.rand(b, device=x_1.device)
        t_view = t.view(b, 1, 1, 1)
        x_t = (1 - t_view) * x_0 + t_view * x_1
        v_target = x_1 - x_0
        v_pred = model(x_t, t, labels)
        return F.mse_loss(v_pred, v_target)

    @torch.no_grad()
    def sample(self, model, n_samples, class_label_idx, size, steps=50):
        model.eval()
        x = torch.randn((n_samples, 1, size, size)).to(device)
        labels = torch.full((n_samples,), class_label_idx, dtype=torch.long).to(device)
        dt = 1.0 / steps
        for i in range(steps):
            t_curr = torch.ones(n_samples).to(device) * (i / steps)
            v_pred = model(x, t_curr, labels)
            x = x + v_pred * dt
        model.train()
        return x

# ReceiptDataset definition (already correct from previous successful execution)
class FloorDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, size=(64, 64), transform=None):
        self.root_dir = root_dir
        self.size = size
        self.transform = transform
        self.image_paths = []

        # Corrected: image_folder should now be 'floorplans_v2' based on unzip output
        image_folder = os.path.join(root_dir, 'floorplans_v2') # Changed to floorplans_v2
        for ext in ['jpg', 'jpeg', 'png']:
            self.image_paths.extend(glob.glob(os.path.join(image_folder, f'*.{ext}')))

        if not self.image_paths:
            raise RuntimeError(f"No images found in {image_folder}. Please check the path and file types.")

        print(f"Found {len(self.image_paths)} floor plan images in {image_folder}")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        img = Image.open(img_path).convert('L') # Convert to grayscale
        label = 0 # Assign a single label for receipts

        if self.transform:
            img = self.transform(img)
        return img, label

# save_model function (copy from original notebook)
def save_model(model, filename="fintech_flow_model.pth"):
    torch.save(model.state_dict(), filename)
    print(f"✅ Model saved to {filename}")


def train_floorplan_model():
    # 1. Prepare Data using ReceiptDataset
    floor_dataset = FloorDataset(
        root_dir='/content/', # Changed root_dir to /content/
        size=(HPARAMS["img_size"], HPARAMS["img_size"]),
        transform=transforms.Compose([
            transforms.Resize((HPARAMS["img_size"], HPARAMS["img_size"])),
            transforms.ToTensor()
        ])
    )
    floor_dataloader = DataLoader(floor_dataset, batch_size=HPARAMS["batch_size"], shuffle=True)

    # 2. Initialize Model and Flow Matching (ConditionalUNet uses HPARAMS["num_classes"] internally)
    model = ConditionalUNet().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=HPARAMS["lr"])
    flow = FlowMatching() # Use Flow Matching manager

    print(f"Starting Flow Matching training for {HPARAMS['epochs']} epochs on Floor Plans...")
    for epoch in range(HPARAMS['epochs']):
        pbar = tqdm(floor_dataloader)
        epoch_loss = 0
        for step, (images, labels) in enumerate(pbar):
            images = images.to(device)
            labels = labels.to(device)

            # Compute Flow Matching Loss
            loss = flow.compute_loss(model, images, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            pbar.set_description(f"Epoch {epoch} | Loss: {loss.item():.4f}")

    return model, flow

def generate_floor_grid(model, flow, n_samples_per_row=4, total_rows=3):
    print("\nGenerating Grid of Synthetic Floor Plans (Euler Step)...")
    steps = HPARAMS["inference_steps"]
    # For a single class (receipts), all samples will have the same label (0)
    generated_floor = flow.sample(model, n_samples=n_samples_per_row * total_rows,
                                     class_label_idx=0, # Fixed label for receipts
                                     size=HPARAMS["img_size"], steps=steps)

    grid = make_grid(generated_floor, nrow=n_samples_per_row, padding=2, normalize=True)
    plt.figure(figsize=(10, 8))
    plt.imshow(grid.permute(1, 2, 0).cpu().numpy(), cmap='gray')
    plt.title(f"Generated Floor Plans (Single Class: {n_samples_per_row*total_rows} samples)")
    plt.axis('off')
    plt.show()

# --- Main execution block for the new task ---
if __name__ == "__main__":
    # 1. Train the Flow Matching model specifically for receipts
    trained_floor_model, floor_flow_manager = train_floorplan_model() # Corrected function name

    # 2. Save the trained model
    save_model(trained_floor_model, "fintech_receipt_flow_model.pth")

    # 3. Visualize the generated receipts
    generate_floor_grid(trained_floor_model, floor_flow_manager, n_samples_per_row=1, total_rows=4)
# Out:
# Using device: cuda
# Found 1000 floor plan images in /content/floorplans_v2
# Starting Flow Matching training for 50 epochs on Floor Plans...
# Epoch 0 | Loss: 1.3064: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s]
# Epoch 1 | Loss: 1.0341: 100%|██████████| 32/32 [00:25<00:00,  1.26it/s]
# Epoch 2 | Loss: 0.9333: 100%|██████████| 32/32 [00:27<00:00,  1.16it/s]
# Epoch 3 | Loss: 0.8329: 100%|██████████| 32/32 [00:30<00:00,  1.05it/s]
# Epoch 4 | Loss: 0.7506:  22%|██▏       | 7/32 [00:07<00:27,  1.11s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3971435965.py in <cell line: 0>()
#     219 if __name__ == "__main__":
#     220     # 1. Train the Flow Matching model specifically for receipts
# --> 221     trained_floor_model, floor_flow_manager = train_floorplan_model() # Corrected function name
#     222
#     223     # 2. Save the trained model
#
# /tmp/ipython-input-3971435965.py in train_floorplan_model()
#     196             optimizer.step()
#     197
# --> 198             epoch_loss += loss.item()
#     199             pbar.set_description(f"Epoch {epoch} | Loss: {loss.item():.4f}")
#     200
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5. Generate New Receipt Image
#
# Now that the model has been trained, we can load it and use it to generate new, synthetic receipt images. This section loads the saved model and utilizes the `generate_single_document` function to create and display a new receipt.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision.utils import make_grid
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import random
import os
from PIL import Image
import glob

# Re-define device and HPARAMS as they were not in the current execution context
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

HPARAMS = {
    "img_size": 256,
    "inference_steps": 100,
    "batch_size": 32,
    "lr": 1e-4,
    "epochs": 50,
    "channels": 1,
    "num_classes": 1 # Updated for receipts only
}

# Re-define model architecture (ConditionalUNet, Block, SinusoidalPositionEmbeddings)
class SinusoidalPositionEmbeddings(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim
    def forward(self, time):
        device = time.device
        half_dim = self.dim // 2
        embeddings = np.log(10000) / (half_dim - 1)
        embeddings = torch.exp(torch.arange(half_dim, device=device) * -embeddings)
        embeddings = time[:, None] * embeddings[None, :]
        embeddings = torch.cat((embeddings.sin(), embeddings.cos()), dim=-1)
        return embeddings

class Block(nn.Module):
    def __init__(self, in_ch, out_ch, time_emb_dim, up=False):
        super().__init__()
        self.time_mlp = nn.Linear(time_emb_dim, out_ch)
        if up:
            self.conv1 = nn.Conv2d(2*in_ch, out_ch, 3, padding=1)
            self.transform = nn.ConvTranspose2d(out_ch, out_ch, 4, 2, 1)
        else:
            self.conv1 = nn.Conv2d(in_ch, out_ch, 3, padding=1)
            self.transform = nn.Conv2d(out_ch, out_ch, 4, 2, 1)
        self.conv2 = nn.Conv2d(out_ch, out_ch, 3, padding=1)
        self.bnorm1 = nn.BatchNorm2d(out_ch)
        self.bnorm2 = nn.BatchNorm2d(out_ch)
        self.relu = nn.ReLU()

    def forward(self, x, t):
        h = self.bnorm1(self.relu(self.conv1(x)))
        time_emb = self.relu(self.time_mlp(t))
        time_emb = time_emb[(..., ) + (None, ) * 2]
        h = h + time_emb
        h = self.bnorm2(self.relu(self.conv2(h)))
        return self.transform(h)

class ConditionalUNet(nn.Module):
    def __init__(self):
        super().__init__()
        img_channels = HPARAMS["channels"]
        down_channels = (32, 64, 128)
        up_channels = (128, 64, 32)
        out_dim = img_channels
        time_emb_dim = 32
        classes = HPARAMS["num_classes"]

        self.time_mlp = nn.Sequential(
            SinusoidalPositionEmbeddings(time_emb_dim),
            nn.Linear(time_emb_dim, time_emb_dim),
            nn.ReLU()
        )
        self.class_emb = nn.Embedding(classes, time_emb_dim)
        self.conv0 = nn.Conv2d(img_channels, down_channels[0], 3, padding=1)
        self.downs = nn.ModuleList([Block(down_channels[i], down_channels[i+1], time_emb_dim) for i in range(len(down_channels)-1)])
        self.ups = nn.ModuleList([Block(up_channels[i], up_channels[i+1], time_emb_dim, up=True) for i in range(len(up_channels)-1)])
        self.output = nn.Conv2d(up_channels[-1], out_dim, 1)

    def forward(self, x, t_float, class_label):
        t = self.time_mlp(t_float)
        c = self.class_emb(class_label)
        t = t + c
        x = self.conv0(x)
        residuals = []
        for down in self.downs:
            x = down(x, t)
            residuals.append(x)
        for up in self.ups:
            residual = residuals.pop()
            x = torch.cat((x, residual), dim=1)
            x = up(x, t)
        return self.output(x)

# Re-define FlowMatching logic
class FlowMatching:
    def __init__(self):
        pass

    def compute_loss(self, model, x_1, labels):
        b = x_1.shape[0]
        x_0 = torch.randn_like(x_1)
        t = torch.rand(b, device=x_1.device)
        t_view = t.view(b, 1, 1, 1)
        x_t = (1 - t_view) * x_0 + t_view * x_1
        v_target = x_1 - x_0
        v_pred = model(x_t, t, labels)
        return F.mse_loss(v_pred, v_target)

    @torch.no_grad()
    def sample(self, model, n_samples, class_label_idx, size, steps=50):
        model.eval()
        x = torch.randn((n_samples, 1, size, size)).to(device)
        labels = torch.full((n_samples,), class_label_idx, dtype=torch.long).to(device)
        dt = 1.0 / steps
        for i in range(steps):
            t_curr = torch.ones(n_samples).to(device) * (i / steps)
            v_pred = model(x, t_curr, labels)
            x = x + v_pred * dt
        model.train()
        return x

# Re-define load_model function (copy from original notebook)
def load_model(filename="fintech_receipt_flow_model.pth"):
    if not os.path.exists(filename):
        print(f"❌ Error: {filename} not found.")
        return None

    # Ensure HPARAMS['num_classes'] is set correctly before initializing model
    # We know from previous steps it was set to 1 for receipts
    model = ConditionalUNet().to(device)
    model.load_state_dict(torch.load(filename, map_location=device))
    model.eval()
    print(f"✅ Model loaded from {filename}")
    return model

# Re-define generate_single_document function (copy from original notebook)
def generate_single_document(model, flow, doc_type='floor_plan'):
    """Generates a single image of the requested type."""
    # For this specific task, we only generate 'receipt' and its label is 0
    label_map = {'receipt': 0}

    if doc_type not in label_map:
        print(f"❌ Unknown type: {doc_type}. Currently only 'floor_plan' is supported for single generation in this context.")
        return

    print(f"🎨 Generating new {doc_type} with ODE Solver...")
    sample_tensor = flow.sample(model, n_samples=1, class_label_idx=label_map[doc_type],
                                size=HPARAMS["img_size"], steps=HPARAMS["inference_steps"])

    # Convert tensor to displayable image
    img = sample_tensor[0].cpu().permute(1, 2, 0).numpy()
    img = (img - img.min()) / (img.max() - img.min()) # Normalize to 0-1

    plt.figure(figsize=(4,4))
    plt.imshow(img, cmap='gray')
    plt.title(f"Generated {doc_type.capitalize()}")
    plt.axis('off')
    plt.show()

# --- Execution for generating a single receipt ---

# Load the previously trained model
loaded_receipt_model = load_model("fintech_receipt_flow_model.pth")

# Initialize FlowMatching class (no state needed, just methods)
receipt_flow_manager = FlowMatching()

# Generate and display a single receipt
if loaded_receipt_model:
    generate_single_document(loaded_receipt_model, receipt_flow_manager, doc_type='receipt')

# %% [markdown]
# #Required Task 11
#
# Download the zip file `floorplans_v2-20251223T170650Z-3-001.zip` which contains a large sample of floorplan images. Your task is to train flow matching model based on these images. Train the model on the floorplan images and create code to generate new synthetic floorplans.
