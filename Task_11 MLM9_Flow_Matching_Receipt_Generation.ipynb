# %% [markdown]
# <a href="https://colab.research.google.com/github/ihstepura/publicgenai/blob/main/Task_11%20MLM9_Flow_Matching_Receipt_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Flow Matching for Receipt Generation
#
# This notebook demonstrates how to train a Flow Matching model to generate synthetic receipt images. We'll cover the entire process from data preparation to model training and image generation. The goal is to create a generative model that can produce realistic-looking receipts based on a small dataset of real receipts.

# %% [markdown]
# ## Setup and Hyperparameters
#
# This section imports necessary libraries and defines global hyperparameters (`HPARAMS`) that configure our model and training process. Understanding these parameters is crucial for customizing the model's behavior and performance.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision.utils import make_grid
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import random
import os
from PIL import Image, ImageDraw

# Check for GPU availability and set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define Hyperparameters
HPARAMS = {
    "img_size": 256,         # Size of the generated images (e.g., 256x256 pixels)
    "inference_steps": 100,  # Number of steps for the ODE solver during sampling (higher = better quality, slower)
    "batch_size": 32,        # Number of images processed per training step
    "lr": 1e-4,              # Learning rate for the Adam optimizer
    "epochs": 50,            # Number of full passes through the training dataset
    "channels": 1,           # Number of image channels (1 for grayscale, 3 for RGB)
    "num_classes": 1         # Number of distinct classes the model should generate (here, only 'receipts')
}
print("Hyperparameters:", HPARAMS)
# Out:
# Using device: cuda
# Hyperparameters: {'img_size': 256, 'inference_steps': 100, 'batch_size': 32, 'lr': 0.0001, 'epochs': 50, 'channels': 1, 'num_classes': 1}

# %% [markdown]
# ## Data Extraction
#
# Before we can train our model, we need to extract the receipt images from the provided ZIP file. This step uses a shell command to decompress the archive into a designated directory.

# %%
# !unzip /content/receipts_sample-20260102T154712Z-3-001.zip -d receipt_images
print("Zip file extracted to 'receipt_images' directory.")
# Out:
# Archive:  /content/receipts_sample-20260102T154712Z-3-001.zip
#   inflating: receipt_images/receipts_sample/receipt_sample_033.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_035.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_035.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_038.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_038.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_039.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_032.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_040.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_044.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_032.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_031.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_045.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_042.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_034.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_039.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_033.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_043.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_046.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_040.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_037.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_044.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_046.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_036.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_034.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_037.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_041.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_036.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_042.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_045.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_031.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_028.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_030.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_029.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_043.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_030.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_027.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_024.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_041.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_025.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_026.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_028.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_026.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_029.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_025.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_022.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_021.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_023.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_027.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_022.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_019.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_020.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_017.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_021.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_018.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_020.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_024.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_019.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_015.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_017.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_016.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_014.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_023.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_013.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_013.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_012.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_010.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_010.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_012.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_016.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_014.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_008.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_009.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_009.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_007.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_006.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_015.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_007.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_011.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_018.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_715.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_713.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_008.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_712.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_712.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_714.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_710.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_011.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_711.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_709.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_709.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_711.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_708.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_710.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_705.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_707.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_706.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_714.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_713.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_706.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_708.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_704.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_705.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_701.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_703.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_700.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_703.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_701.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_700.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_702.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_698.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_698.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_697.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_699.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_702.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_697.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_696.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_694.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_695.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_693.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_694.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_693.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_704.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_695.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_690.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_689.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_691.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_690.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_691.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_687.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_686.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_696.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_687.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_688.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_686.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_684.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_684.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_685.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_685.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_692.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_683.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_682.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_692.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_682.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_683.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_699.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_681.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_680.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_681.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_688.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_676.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_679.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_677.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_678.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_689.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_678.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_676.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_674.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_675.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_675.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_674.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_673.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_671.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_672.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_672.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_673.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_679.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_677.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_670.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_669.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_671.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_680.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_667.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_670.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_668.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_669.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_666.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_668.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_707.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_665.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_665.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_664.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_666.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_667.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_663.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_662.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_661.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_664.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_662.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_660.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_663.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_660.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_659.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_658.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_659.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_658.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_657.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_657.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_656.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_655.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_654.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_656.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_654.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_652.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_653.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_655.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_650.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_653.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_650.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_651.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_652.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_648.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_649.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_651.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_641.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_649.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_646.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_647.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_661.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_647.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_648.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_644.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_644.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_646.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_642.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_645.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_640.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_640.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_641.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_643.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_638.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_006.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_637.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_639.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_636.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_636.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_635.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_637.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_639.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_634.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_633.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_638.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_642.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_632.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_634.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_630.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_633.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_645.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_631.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_632.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_628.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_629.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_630.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_629.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_643.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_627.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_626.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_626.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_627.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_625.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_625.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_622.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_624.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_624.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_635.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_622.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_623.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_618.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_621.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_621.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_623.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_631.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_619.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_619.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_620.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_005.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_616.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_620.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_628.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_617.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_616.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_615.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_617.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_613.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_618.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_614.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_615.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_611.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_612.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_614.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_613.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_610.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_609.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_609.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_608.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_610.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_612.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_608.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_606.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_605.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_607.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_606.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_611.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_605.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_604.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_603.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_603.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_602.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_607.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_602.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_600.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_599.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_598.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_604.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_596.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_597.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_601.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_597.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_601.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_596.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_594.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_599.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_595.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_595.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_593.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_592.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_591.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_593.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_592.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_589.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_590.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_594.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_591.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_587.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_590.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_588.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_589.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_586.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_588.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_587.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_585.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_582.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_585.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_586.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_582.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_598.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_583.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_584.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_584.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_583.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_579.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_581.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_580.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_580.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_579.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_577.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_578.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_581.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_578.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_576.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_575.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_576.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_577.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_575.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_570.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_572.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_574.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_574.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_572.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_573.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_571.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_569.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_570.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_569.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_567.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_568.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_567.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_568.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_566.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_564.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_565.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_566.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_565.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_571.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_562.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_563.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_562.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_564.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_563.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_561.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_561.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_560.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_560.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_559.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_559.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_557.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_557.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_558.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_553.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_573.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_558.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_556.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_556.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_555.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_555.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_554.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_553.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_552.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_554.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_552.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_550.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_551.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_551.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_549.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_550.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_549.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_546.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_547.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_548.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_600.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_545.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_544.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_545.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_546.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_544.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_547.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_543.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_543.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_542.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_548.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_541.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_542.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_540.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_539.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_538.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_540.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_535.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_537.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_539.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_541.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_538.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_536.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_532.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_534.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_535.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_536.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_533.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_532.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_533.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_530.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_529.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_528.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_531.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_527.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_531.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_530.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_537.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_527.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_528.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_524.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_529.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_526.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_523.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_525.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_526.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_522.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_520.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_499.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_534.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_518.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_521.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_523.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_524.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_521.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_520.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_522.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_519.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_517.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_515.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_516.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_517.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_514.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_518.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_519.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_515.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_516.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_498.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_431.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_498.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_497.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_513.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_430.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_525.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_350.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_431.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_514.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_497.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_394.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_496.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_350.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_430.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_473.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_381.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_513.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_320.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_363.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_473.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_394.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_306.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_457.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_363.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_326.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_496.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_446.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_338.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_305.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_381.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_429.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_275.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_349.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_417.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_319.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_282.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_464.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_411.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_512.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_484.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_337.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_380.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_457.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_393.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_440.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_506.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_374.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_349.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_387.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_362.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_436.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_356.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_445.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_429.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_262.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_268.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_262.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_417.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_463.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_312.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_305.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_495.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_281.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_505.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_410.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_472.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_393.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_274.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_325.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_299.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_380.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_274.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_512.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_255.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_387.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_456.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_374.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_472.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_445.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_440.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_362.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_356.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_436.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_348.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_495.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_331.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_505.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_268.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_463.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_337.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_325.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_244.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_318.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_287.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_318.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_312.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_416.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_244.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_281.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_293.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_304.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_511.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_483.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_237.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_428.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_298.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_255.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_236.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_237.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_261.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_236.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_456.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_439.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_243.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_287.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_489.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_230.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_386.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_273.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_511.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_373.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_444.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_483.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_224.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_368.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_409.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_379.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_355.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_261.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_410.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_361.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_331.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_254.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_336.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_494.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_348.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_223.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_343.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_428.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_224.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_324.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_249.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_280.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_267.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_435.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_311.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_225.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_462.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_423.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_416.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_213.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_213.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_212.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_304.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_218.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_230.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_311.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_504.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_471.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_392.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_235.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_206.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_260.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_298.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_206.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_211.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_212.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_002.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_317.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_292.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_205.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_205.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_223.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_243.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_399.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_489.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_254.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_392.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_267.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_199.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_198.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_361.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_193.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_379.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_273.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_235.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_404.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_192.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_198.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_482.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_368.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_373.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_204.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_199.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_197.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_286.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_444.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_297.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_478.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_187.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_355.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_186.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_185.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_510.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_229.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_386.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_192.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_187.jpg
# ...
#   inflating: receipt_images/receipts_sample/receipt_sample_095.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_448.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_396.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_270.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_328.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_480.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_114.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_419.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_264.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_276.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_177.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_500.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_294.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_226.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_413.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_327.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_151.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_419.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_475.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_383.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_300.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_376.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_164.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_001.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_119.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_406.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_170.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_215.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_087.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_257.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_491.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_465.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_389.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_189.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_358.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_194.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_220.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_157.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_507.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_106.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_339.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_352.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_283.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_344.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_081.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_468.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_424.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_126.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_370.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_333.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_061.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_365.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_246.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_307.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_074.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_442.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_485.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_239.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_321.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_182.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_139.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_067.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_432.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_412.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_057.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_145.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_232.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_201.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_100.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_251.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_132.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_459.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_289.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_270.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_452.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_208.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_396.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_447.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_113.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_401.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_231.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_150.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_389.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_479.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_314.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_307.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_219.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_125.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_074.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_382.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_250.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_056.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_288.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_474.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_500.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_170.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_327.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_313.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_263.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_118.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_375.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_294.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_395.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_441.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_405.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_100.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_479.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_138.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_332.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_094.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_369.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_388.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_269.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_451.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_245.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_424.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_256.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_226.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_067.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_465.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_087.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_418.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_080.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_177.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_201.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_144.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_432.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_344.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_061.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_485.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_194.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_468.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_300.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_106.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_364.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_351.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_132.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_113.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_321.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_214.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_181.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_339.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_099.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_357.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_490.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_276.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_207.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_283.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_164.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_437.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_458.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_447.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_400.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_412.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_056.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_188.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_263.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_351.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_478.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_238.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_112.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_231.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_507.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_256.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_250.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_188.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_066.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_214.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_157.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_313.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_105.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_245.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_423.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_332.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_441.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_474.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_073.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_451.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_464.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_418.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_156.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_163.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_364.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_219.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_080.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_382.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_086.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_405.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_176.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_411.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_125.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_181.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_299.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_200.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_144.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_343.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_293.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_238.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_193.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_306.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_094.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_003.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_288.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_506.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_395.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_467.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_225.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_320.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_400.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_326.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_375.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_490.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_138.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_060.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_269.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_005.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_207.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_458.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_118.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_369.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_484.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_169.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_499.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_150.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_388.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_338.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_357.jpg
#   inflating: receipt_images/receipts_sample/receipt_sample_282.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_446.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_131.txt
#   inflating: receipt_images/receipts_sample/receipt_sample_275.txt
# Zip file extracted to 'receipt_images' directory.

# %% [markdown]
# ## Model Architecture and Flow Matching Logic
#
# This section defines the core components of our generative model: the `ConditionalUNet` architecture, which is a neural network designed for image generation tasks, and the `FlowMatching` class, which implements the training and sampling logic for flow-based generative models. It also includes our custom `ReceiptDataset` to handle loading and transforming the image data.
#
# ### SinusoidalPositionEmbeddings
# This class creates sinusoidal positional embeddings for time steps. In generative models like Flow Matching, these embeddings help the network understand the 'progress' of the generation process (from noise to data) by providing a unique, continuous representation for each time step.
#
# ### Block
# The `Block` class represents a fundamental building block of the U-Net architecture. It consists of convolutional layers, batch normalization, and ReLU activations. It also integrates time embeddings, allowing the model to condition its output on the current time step in the flow. The `transform` layer handles downsampling (Conv2d with stride 2) or upsampling (ConvTranspose2d) within the U-Net.
#
# ### ConditionalUNet
# The `ConditionalUNet` is the main neural network architecture. It's a U-Net variant that processes images and is 'conditional' because it takes both the image, the current time step (`t`), and a class label (though here we only have one class) as input. This allows the model to learn to generate specific types of images. It consists of a series of `Block`s for downsampling (`downs`) and upsampling (`ups`), with skip connections (residuals) to preserve detail.
#
# ### FlowMatching
# This class encapsulates the core logic of the Flow Matching generative process. Unlike diffusion models that iteratively add and remove noise, Flow Matching learns a continuous-time vector field that smoothly transports a simple prior distribution (e.g., Gaussian noise, `x_0`) to a complex target distribution (the real data, `x_1`).
#
# -   **`compute_loss`**: Calculates the loss for training. It samples `x_0` (noise), `x_1` (real data), and a random time `t`. It then computes an intermediate point `x_t` on the straight line path between `x_0` and `x_1`, and asks the model to predict the velocity vector (`v_target`) that points from `x_0` to `x_1`. The loss is the mean squared error between the model's predicted velocity (`v_pred`) and the true target velocity.
# -   **`sample`**: Implements an Euler ODE solver for generating new images. Starting from random noise (`x_0` at `t=0`), it iteratively updates the image by following the velocity field predicted by the trained `ConditionalUNet`. This process effectively traces a path from noise to a generated image (`x_1` at `t=1`).
#
# ### ReceiptDataset
# This custom `torch.utils.data.Dataset` class is responsible for loading our receipt images. It reads image files from the specified directory, converts them to grayscale, resizes them to the model's input dimensions, and transforms them into PyTorch tensors. Since we are only generating receipts, it assigns a single class label (0) to all images.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision.utils import make_grid
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import random
import os
from PIL import Image
import glob

# Re-define device and HPARAMS as they were not in the current execution context
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

HPARAMS = {
    "img_size": 256,
    "inference_steps": 100,
    "batch_size": 32,
    "lr": 1e-4,
    "epochs": 50,
    "channels": 1,
    "num_classes": 1 # Updated for receipts only
}

# Re-define model architecture (ConditionalUNet, Block, SinusoidalPositionEmbeddings)
class SinusoidalPositionEmbeddings(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim
    def forward(self, time):
        device = time.device
        half_dim = self.dim // 2
        embeddings = np.log(10000) / (half_dim - 1)
        embeddings = torch.exp(torch.arange(half_dim, device=device) * -embeddings)
        embeddings = time[:, None] * embeddings[None, :]
        embeddings = torch.cat((embeddings.sin(), embeddings.cos()), dim=-1)
        return embeddings

class Block(nn.Module):
    def __init__(self, in_ch, out_ch, time_emb_dim, up=False):
        super().__init__()
        self.time_mlp = nn.Linear(time_emb_dim, out_ch)
        if up:
            self.conv1 = nn.Conv2d(2*in_ch, out_ch, 3, padding=1)
            self.transform = nn.ConvTranspose2d(out_ch, out_ch, 4, 2, 1)
        else:
            self.conv1 = nn.Conv2d(in_ch, out_ch, 3, padding=1)
            self.transform = nn.Conv2d(out_ch, out_ch, 4, 2, 1)
        self.conv2 = nn.Conv2d(out_ch, out_ch, 3, padding=1)
        self.bnorm1 = nn.BatchNorm2d(out_ch)
        self.bnorm2 = nn.BatchNorm2d(out_ch)
        self.relu = nn.ReLU()

    def forward(self, x, t):
        h = self.bnorm1(self.relu(self.conv1(x)))
        time_emb = self.relu(self.time_mlp(t))
        time_emb = time_emb[(..., ) + (None, ) * 2]
        h = h + time_emb
        h = self.bnorm2(self.relu(self.conv2(h)))
        return self.transform(h)

class ConditionalUNet(nn.Module):
    def __init__(self):
        super().__init__()
        img_channels = HPARAMS["channels"]
        down_channels = (32, 64, 128)
        up_channels = (128, 64, 32)
        out_dim = img_channels
        time_emb_dim = 32
        classes = HPARAMS["num_classes"]

        self.time_mlp = nn.Sequential(
            SinusoidalPositionEmbeddings(time_emb_dim),
            nn.Linear(time_emb_dim, time_emb_dim),
            nn.ReLU()
        )
        self.class_emb = nn.Embedding(classes, time_emb_dim)
        self.conv0 = nn.Conv2d(img_channels, down_channels[0], 3, padding=1)
        self.downs = nn.ModuleList([Block(down_channels[i], down_channels[i+1], time_emb_dim) for i in range(len(down_channels)-1)])
        self.ups = nn.ModuleList([Block(up_channels[i], up_channels[i+1], time_emb_dim, up=True) for i in range(len(up_channels)-1)])
        self.output = nn.Conv2d(up_channels[-1], out_dim, 1)

    def forward(self, x, t_float, class_label):
        t = self.time_mlp(t_float)
        c = self.class_emb(class_label)
        t = t + c
        x = self.conv0(x)
        residuals = []
        for down in self.downs:
            x = down(x, t)
            residuals.append(x)
        for up in self.ups:
            residual = residuals.pop()
            x = torch.cat((x, residual), dim=1)
            x = up(x, t)
        return self.output(x)

# Re-define FlowMatching logic
class FlowMatching:
    def __init__(self):
        pass

    def compute_loss(self, model, x_1, labels):
        b = x_1.shape[0]
        x_0 = torch.randn_like(x_1)
        t = torch.rand(b, device=x_1.device)
        t_view = t.view(b, 1, 1, 1)
        x_t = (1 - t_view) * x_0 + t_view * x_1
        v_target = x_1 - x_0
        v_pred = model(x_t, t, labels)
        return F.mse_loss(v_pred, v_target)

    @torch.no_grad()
    def sample(self, model, n_samples, class_label_idx, size, steps=50):
        model.eval()
        x = torch.randn((n_samples, 1, size, size)).to(device)
        labels = torch.full((n_samples,), class_label_idx, dtype=torch.long).to(device)
        dt = 1.0 / steps
        for i in range(steps):
            t_curr = torch.ones(n_samples).to(device) * (i / steps)
            v_pred = model(x, t_curr, labels)
            x = x + v_pred * dt
        model.train()
        return x

# ReceiptDataset definition (already correct from previous successful execution)
class ReceiptDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, size=(64, 64), transform=None):
        self.root_dir = root_dir
        self.size = size
        self.transform = transform
        self.image_paths = []

        # Corrected: image_folder should now be 'receipts_sample' based on unzip output
        image_folder = os.path.join(root_dir, 'receipts_sample')
        for ext in ['jpg', 'jpeg', 'png']:
            self.image_paths.extend(glob.glob(os.path.join(image_folder, f'*.{ext}')))

        if not self.image_paths:
            raise RuntimeError(f"No images found in {image_folder}. Please check the path and file types.")

        print(f"Found {len(self.image_paths)} receipt images in {image_folder}")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        img = Image.open(img_path).convert('L') # Convert to grayscale
        label = 0 # Assign a single label for receipts

        if self.transform:
            img = self.transform(img)
        return img, label

# save_model function (copy from original notebook)
def save_model(model, filename="fintech_flow_model.pth"):
    torch.save(model.state_dict(), filename)
    print(f"✅ Model saved to {filename}")


def train_receipt_model():
    # 1. Prepare Data using ReceiptDataset
    receipt_dataset = ReceiptDataset(
        root_dir='receipt_images',
        size=(HPARAMS["img_size"], HPARAMS["img_size"]),
        transform=transforms.Compose([
            transforms.Resize((HPARAMS["img_size"], HPARAMS["img_size"])),
            transforms.ToTensor()
        ])
    )
    receipt_dataloader = DataLoader(receipt_dataset, batch_size=HPARAMS["batch_size"], shuffle=True)

    # 2. Initialize Model and Flow Matching (ConditionalUNet uses HPARAMS["num_classes"] internally)
    model = ConditionalUNet().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=HPARAMS["lr"])
    flow = FlowMatching() # Use Flow Matching manager

    print(f"Starting Flow Matching training for {HPARAMS['epochs']} epochs on Receipts...")
    for epoch in range(HPARAMS['epochs']):
        pbar = tqdm(receipt_dataloader)
        epoch_loss = 0
        for step, (images, labels) in enumerate(pbar):
            images = images.to(device)
            labels = labels.to(device)

            # Compute Flow Matching Loss
            loss = flow.compute_loss(model, images, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            pbar.set_description(f"Epoch {epoch} | Loss: {loss.item():.4f}")

    return model, flow

def generate_receipt_grid(model, flow, n_samples_per_row=4, total_rows=3):
    print("\nGenerating Grid of Synthetic Receipts (Euler Step)...")
    steps = HPARAMS["inference_steps"]
    # For a single class (receipts), all samples will have the same label (0)
    generated_receipts = flow.sample(model, n_samples=n_samples_per_row * total_rows,
                                     class_label_idx=0, # Fixed label for receipts
                                     size=HPARAMS["img_size"], steps=steps)

    grid = make_grid(generated_receipts, nrow=n_samples_per_row, padding=2, normalize=True)
    plt.figure(figsize=(10, 8))
    plt.imshow(grid.permute(1, 2, 0).cpu().numpy(), cmap='gray')
    plt.title(f"Generated Receipts (Single Class: {n_samples_per_row*total_rows} samples)")
    plt.axis('off')
    plt.show()

# --- Main execution block for the new task ---
if __name__ == "__main__":
    # 1. Train the Flow Matching model specifically for receipts
    trained_receipt_model, receipt_flow_manager = train_receipt_model()

    # 2. Save the trained model
    save_model(trained_receipt_model, "fintech_receipt_flow_model.pth")

    # 3. Visualize the generated receipts
    generate_receipt_grid(trained_receipt_model, receipt_flow_manager, n_samples_per_row=1, total_rows=4)
# Out:
# Using device: cuda
# Found 714 receipt images in receipt_images/receipts_sample
# Starting Flow Matching training for 50 epochs on Receipts...
# Epoch 0 | Loss: 1.2781: 100%|██████████| 23/23 [00:24<00:00,  1.06s/it]
# Epoch 1 | Loss: 0.8480: 100%|██████████| 23/23 [00:23<00:00,  1.04s/it]
# Epoch 2 | Loss: 0.7301: 100%|██████████| 23/23 [00:25<00:00,  1.11s/it]
# Epoch 3 | Loss: 0.7510: 100%|██████████| 23/23 [00:26<00:00,  1.14s/it]
# Epoch 4 | Loss: 0.6251: 100%|██████████| 23/23 [00:24<00:00,  1.07s/it]
# Epoch 5 | Loss: 0.5749: 100%|██████████| 23/23 [00:24<00:00,  1.08s/it]
# Epoch 6 | Loss: 0.6172: 100%|██████████| 23/23 [00:25<00:00,  1.10s/it]
# Epoch 7 | Loss: 0.5341: 100%|██████████| 23/23 [00:24<00:00,  1.08s/it]
# Epoch 8 | Loss: 0.4144: 100%|██████████| 23/23 [00:24<00:00,  1.08s/it]
# Epoch 9 | Loss: 0.4826: 100%|██████████| 23/23 [00:25<00:00,  1.10s/it]
# Epoch 10 | Loss: 0.2847: 100%|██████████| 23/23 [00:25<00:00,  1.09s/it]
# Epoch 11 | Loss: 0.3504:  61%|██████    | 14/23 [00:17<00:10,  1.22s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2062535586.py in <cell line: 0>()
#     219 if __name__ == "__main__":
#     220     # 1. Train the Flow Matching model specifically for receipts
# --> 221     trained_receipt_model, receipt_flow_manager = train_receipt_model()
#     222
#     223     # 2. Save the trained model
#
# /tmp/ipython-input-2062535586.py in train_receipt_model()
#     196             optimizer.step()
#     197
# --> 198             epoch_loss += loss.item()
#     199             pbar.set_description(f"Epoch {epoch} | Loss: {loss.item():.4f}")
#     200
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5. Generate New Receipt Image
#
# Now that the model has been trained, we can load it and use it to generate new, synthetic receipt images. This section loads the saved model and utilizes the `generate_single_document` function to create and display a new receipt.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision.utils import make_grid
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import random
import os
from PIL import Image
import glob

# Re-define device and HPARAMS as they were not in the current execution context
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

HPARAMS = {
    "img_size": 256,
    "inference_steps": 100,
    "batch_size": 32,
    "lr": 1e-4,
    "epochs": 50,
    "channels": 1,
    "num_classes": 1 # Updated for receipts only
}

# Re-define model architecture (ConditionalUNet, Block, SinusoidalPositionEmbeddings)
class SinusoidalPositionEmbeddings(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim
    def forward(self, time):
        device = time.device
        half_dim = self.dim // 2
        embeddings = np.log(10000) / (half_dim - 1)
        embeddings = torch.exp(torch.arange(half_dim, device=device) * -embeddings)
        embeddings = time[:, None] * embeddings[None, :]
        embeddings = torch.cat((embeddings.sin(), embeddings.cos()), dim=-1)
        return embeddings

class Block(nn.Module):
    def __init__(self, in_ch, out_ch, time_emb_dim, up=False):
        super().__init__()
        self.time_mlp = nn.Linear(time_emb_dim, out_ch)
        if up:
            self.conv1 = nn.Conv2d(2*in_ch, out_ch, 3, padding=1)
            self.transform = nn.ConvTranspose2d(out_ch, out_ch, 4, 2, 1)
        else:
            self.conv1 = nn.Conv2d(in_ch, out_ch, 3, padding=1)
            self.transform = nn.Conv2d(out_ch, out_ch, 4, 2, 1)
        self.conv2 = nn.Conv2d(out_ch, out_ch, 3, padding=1)
        self.bnorm1 = nn.BatchNorm2d(out_ch)
        self.bnorm2 = nn.BatchNorm2d(out_ch)
        self.relu = nn.ReLU()

    def forward(self, x, t):
        h = self.bnorm1(self.relu(self.conv1(x)))
        time_emb = self.relu(self.time_mlp(t))
        time_emb = time_emb[(..., ) + (None, ) * 2]
        h = h + time_emb
        h = self.bnorm2(self.relu(self.conv2(h)))
        return self.transform(h)

class ConditionalUNet(nn.Module):
    def __init__(self):
        super().__init__()
        img_channels = HPARAMS["channels"]
        down_channels = (32, 64, 128)
        up_channels = (128, 64, 32)
        out_dim = img_channels
        time_emb_dim = 32
        classes = HPARAMS["num_classes"]

        self.time_mlp = nn.Sequential(
            SinusoidalPositionEmbeddings(time_emb_dim),
            nn.Linear(time_emb_dim, time_emb_dim),
            nn.ReLU()
        )
        self.class_emb = nn.Embedding(classes, time_emb_dim)
        self.conv0 = nn.Conv2d(img_channels, down_channels[0], 3, padding=1)
        self.downs = nn.ModuleList([Block(down_channels[i], down_channels[i+1], time_emb_dim) for i in range(len(down_channels)-1)])
        self.ups = nn.ModuleList([Block(up_channels[i], up_channels[i+1], time_emb_dim, up=True) for i in range(len(up_channels)-1)])
        self.output = nn.Conv2d(up_channels[-1], out_dim, 1)

    def forward(self, x, t_float, class_label):
        t = self.time_mlp(t_float)
        c = self.class_emb(class_label)
        t = t + c
        x = self.conv0(x)
        residuals = []
        for down in self.downs:
            x = down(x, t)
            residuals.append(x)
        for up in self.ups:
            residual = residuals.pop()
            x = torch.cat((x, residual), dim=1)
            x = up(x, t)
        return self.output(x)

# Re-define FlowMatching logic
class FlowMatching:
    def __init__(self):
        pass

    def compute_loss(self, model, x_1, labels):
        b = x_1.shape[0]
        x_0 = torch.randn_like(x_1)
        t = torch.rand(b, device=x_1.device)
        t_view = t.view(b, 1, 1, 1)
        x_t = (1 - t_view) * x_0 + t_view * x_1
        v_target = x_1 - x_0
        v_pred = model(x_t, t, labels)
        return F.mse_loss(v_pred, v_target)

    @torch.no_grad()
    def sample(self, model, n_samples, class_label_idx, size, steps=50):
        model.eval()
        x = torch.randn((n_samples, 1, size, size)).to(device)
        labels = torch.full((n_samples,), class_label_idx, dtype=torch.long).to(device)
        dt = 1.0 / steps
        for i in range(steps):
            t_curr = torch.ones(n_samples).to(device) * (i / steps)
            v_pred = model(x, t_curr, labels)
            x = x + v_pred * dt
        model.train()
        return x

# Re-define load_model function (copy from original notebook)
def load_model(filename="fintech_receipt_flow_model.pth"):
    if not os.path.exists(filename):
        print(f"❌ Error: {filename} not found.")
        return None

    # Ensure HPARAMS['num_classes'] is set correctly before initializing model
    # We know from previous steps it was set to 1 for receipts
    model = ConditionalUNet().to(device)
    model.load_state_dict(torch.load(filename, map_location=device))
    model.eval()
    print(f"✅ Model loaded from {filename}")
    return model

# Re-define generate_single_document function (copy from original notebook)
def generate_single_document(model, flow, doc_type='receipt'):
    """Generates a single image of the requested type."""
    # For this specific task, we only generate 'receipt' and its label is 0
    label_map = {'receipt': 0}

    if doc_type not in label_map:
        print(f"❌ Unknown type: {doc_type}. Currently only 'receipt' is supported for single generation in this context.")
        return

    print(f"🎨 Generating new {doc_type} with ODE Solver...")
    sample_tensor = flow.sample(model, n_samples=1, class_label_idx=label_map[doc_type],
                                size=HPARAMS["img_size"], steps=HPARAMS["inference_steps"])

    # Convert tensor to displayable image
    img = sample_tensor[0].cpu().permute(1, 2, 0).numpy()
    img = (img - img.min()) / (img.max() - img.min()) # Normalize to 0-1

    plt.figure(figsize=(4,4))
    plt.imshow(img, cmap='gray')
    plt.title(f"Generated {doc_type.capitalize()}")
    plt.axis('off')
    plt.show()

# --- Execution for generating a single receipt ---

# Load the previously trained model
loaded_receipt_model = load_model("fintech_receipt_flow_model.pth")

# Initialize FlowMatching class (no state needed, just methods)
receipt_flow_manager = FlowMatching()

# Generate and display a single receipt
if loaded_receipt_model:
    generate_single_document(loaded_receipt_model, receipt_flow_manager, doc_type='receipt')

# %% [markdown]
# #Required Task 11
#
# Download the zip file `floorplans_v2-20251223T170650Z-3-001.zip` which contains a large sample of floorplan images. Your task is to train flow matching model based on these images. Train the model on the floorplan images and create code to generate new synthetic floorplans.
